# %% [markdown]
# For many users, it may be valuable to pull together some particular properties that can be summarized to a simple value per each species record and view them in a spreadsheet program of one kind or another in order to slice the data in various ways or run reports. This notebook runs through all of the data generated, making a number of key decisions about how to summarize, and generates a flat CSV output in the cache folder for this type of use.

# %%
import pandas as pd
import json
from IPython.display import display

# %%
taxonomy_lookup = dict()

with open('../cache/itis.json', 'r') as f:
    itis_species = json.loads(f.read())
    f.close()

for record in [i for i in itis_species if "data" in i.keys()]:
    valid_itis_doc = next((i for i in record["data"] if i["usage"] in ["valid","accepted"]), None)
    if valid_itis_doc is not None:
        for k, v in record["parameters"].items():
            itis_lookup_identifier = v
        taxonomy_lookup[itis_lookup_identifier] = {
            "taxonomic_reference": "ITIS",
            "taxonomic_rank": valid_itis_doc["rank"]
        }
        for i in valid_itis_doc["biological_taxonomy"]:
            taxonomy_lookup[itis_lookup_identifier][i["rank"]] = i["name"]

with open('../cache/worms.json', 'r') as f:
    worms_species = json.loads(f.read())
    f.close()
    
for w in [i for i in worms_species if i["processing_metadata"]["status"] != "error"]:
    worms_accepted = next((i for i in w["data"] if i["status"] == "accepted"), None)
    if worms_accepted is not None:
        lookup_name = w["processing_metadata"]["api"].split("/")[-1].split("?")[0]
        taxonomy_lookup[lookup_name] = {
            "taxonomic_reference": "WoRMS",
            "taxonomic_rank": worms_accepted["rank"]
        }
        for i in worms_accepted["biological_taxonomy"]:
            taxonomy_lookup[lookup_name][i["rank"]] = i["name"]

# %%
with open('../cache/workplan_species.json', 'r') as f:
    workplan_species = json.loads(f.read())
    f.close()

for spp in workplan_species:
    if spp["ITIS TSN"] in taxonomy_lookup.keys():
        taxonomy_record = taxonomy_lookup[spp["ITIS TSN"]]
    elif spp["Lookup Name"] in taxonomy_lookup.keys():
        taxonomy_record = taxonomy_lookup[spp["Lookup Name"]]
    else:
        taxonomy_record = None
    if taxonomy_record is not None:
        for k, v in taxonomy_record.items():
            spp[k] = v

# %%
with open('../cache/tess.json', 'r') as f:
    tess_data = json.loads(f.read())
    f.close

tess_lookup = dict()
for r in [i for i in tess_data if "data" in i.keys()]:
    lookup_id = r["processing_metadata"]["api"].split("=")[-1].replace("]","").replace('"','')
    sp_records = r["data"]["SPECIES_DETAIL"]
    if not isinstance(sp_records, list):
        sp_records = [sp_records]
    tess_lookup[lookup_id] = {
        "STATUS": ",".join(list(set([i["STATUS"] for i in sp_records]))),
        "STATUS_TEXT": ",".join(list(set([i["STATUS_TEXT"] for i in sp_records]))),
        "ECOS_SPCODE": ",".join(list(set([i["SPCODE"] for i in sp_records])))
    }

for spp in workplan_species:
    if spp["ITIS TSN"] in tess_lookup.keys():
        tess_record = tess_lookup[spp["ITIS TSN"]]
    elif spp["Lookup Name"] in tess_lookup.keys():
        tess_record = tess_lookup[spp["Lookup Name"]]
    else:
        tess_record = None
    if tess_record is not None:
        for k, v in tess_record.items():
            spp[k] = v

# %%
with open('../cache/iucn.json', 'r') as f:
    iucn_data = json.loads(f.read())
    f.close

iucn_lookup = dict()
for r in [i for i in iucn_data if i["processing_metadata"]["status"] == "success"]:
    iucn_lookup[r["parameters"]["Scientific Name"]] = {
        "iucn_reference": r["data"]["doi"],
        "iucn_status_code": r["data"]["iucn_status_code"],
        "iucn_status_name": r["data"]["iucn_status_name"],
        "iucn_population_trend": r["data"]["iucn_population_trend"],
        "iucn_record_date": r["data"]["record_date"]
    }

for spp in [i for i in workplan_species if i["Lookup Name"] in iucn_lookup.keys()]:
    iucn_record = iucn_lookup[spp["Lookup Name"]]
    for k, v in iucn_record.items():
        spp[k] = v

# %%
with open('../cache/natureserve.json', 'r') as f:
    natureserve_data = json.loads(f.read())
    f.close

natureserve_lookup = dict()
for r in [i for i in natureserve_data if i["processing_metadata"]["status"] == "success"]:
    natureserve_lookup[r["parameters"]["Scientific Name"]] = {
        "natureserve_reference": r["data"]["natureServeGlobalConcept"]["natureServeExplorerURI"],
        "natureserve_status": r["data"]["roundedNationalConservationStatus"]
    }
    try:
        natureserve_lookup[r["parameters"]["Scientific Name"]]["natureserve_last_review_date"] = r["NatureServe Species"]["nationalConservationStatus"]["@lastReviewedDate"]
    except:
        natureserve_lookup[r["parameters"]["Scientific Name"]]["natureserve_last_review_date"] = "unknown"

for spp in [i for i in workplan_species if i["Lookup Name"] in natureserve_lookup.keys()]:
    natureserve_record = natureserve_lookup[spp["Lookup Name"]]
    for k, v in natureserve_record.items():
        spp[k] = v
        
natureserve_data = None
natureserve_lookup = None

# %%
with open('../cache/sgcn.json', 'r') as f:
    sgcn_data = json.loads(f.read())
    f.close()

sgcn_lookup = dict()
for r in [i for i in sgcn_data if i["processing_metadata"]["status"] == "success"]:
    sgcn_lookup[r["parameters"]["Scientific Name"]] = {
        "sgcn_statelist_2005": r["data"]["statelist_2005"],
        "sgcn_statelist_2015": r["data"]["statelist_2015"]
    }

for spp in [i for i in workplan_species if i["Lookup Name"] in sgcn_lookup.keys()]:
    for k, v in sgcn_lookup[spp["Lookup Name"]].items():
        spp[k] = v

sgcn_data = None
sgcn_lookup = None

# %%
with open('../cache/gbif.json', 'r') as f:
    gbif_data = json.loads(f.read())
    f.close()

gbif_lookup = dict()
for r in [i for i in gbif_data if i["processing_metadata"]["status"] == "success"]:
    gbif_lookup[r["parameters"]["Scientific Name"]] = {
        "gbif_reference": r["data"]["resolvable_identifier"],
        "gbif_taxonomic_status": r["data"]["TaxonomicStatus"]
    }
    if "count" in r["data"]["Occurrence Summary"].keys():
        gbif_lookup[r["parameters"]["Scientific Name"]]["gbif_occurrence_records"] = r["data"]["Occurrence Summary"]["count"]
    else:
        gbif_lookup[r["parameters"]["Scientific Name"]]["gbif_occurrence_records"] = 0

for spp in [i for i in workplan_species if i["Lookup Name"] in gbif_lookup.keys()]:
    for k, v in gbif_lookup[spp["Lookup Name"]].items():
        spp[k] = v

gbif_data = None
gbif_lookup = None

# %%
with open('../cache/xdd.json', 'r') as f:
    xdd_data = json.loads(f.read())
    f.close()

xdd_lookup = dict()
for r in [i for i in xdd_data if i["processing_metadata"]["status"] == "success"]:
    xdd_lookup[r["parameters"]["Search Term"]] = {
        "xdd_reference": r["processing_metadata"]["api"],
        "xdd_number_docs": len(r["data"])
    }

for spp in [i for i in workplan_species if i["Lookup Name"] in xdd_lookup.keys()]:
    for k, v in xdd_lookup[spp["Lookup Name"]].items():
        spp[k] = v

xdd_data = None
xdd_lookup = None

# %%
with open('../cache/sb_datarelease.json', 'r') as f:
    sb_data = json.loads(f.read())
    f.close()

sb_lookup = dict()
for r in [i for i in sb_data if "data" in i.keys()]:
    sb_lookup[r["parameters"]["q"]] = {
        "sb_reference": r["processing_metadata"]["api"],
        "sb_number_items": len(r["data"])
    }

for spp in [i for i in workplan_species if i["Lookup Name"] in sb_lookup.keys()]:
    for k, v in sb_lookup[spp["Lookup Name"]].items():
        spp[k] = v

sb_data = None
sb_lookup = None

# %%
with open('../cache/gap.json', 'r') as f:
    gap_data = json.loads(f.read())
    f.close()

with open('../cache/gap_metrics.json', 'r') as f:
    gap_metrics = json.loads(f.read())
    f.close()

gap_lookup = list()
for r in [i for i in gap_data if "data" in i.keys()]:
    gap_lookup.append({
        "scientific_name_source": r["parameters"]["Name Source"],
        "scientific_name": r["parameters"]["Scientific Name"],
        "GAP_SpeciesCode": r["data"]["GAP_SpeciesCode"],
        "GAP_StatesWithHabitat": ",".join([st["state_name"] for st in next(s for s in gap_metrics if s["GAP_SpeciesCode"] == r["data"]["GAP_SpeciesCode"])["State Metrics"]])
    })

for spp in workplan_species:
    check_list = [spp["Lookup Name"]]
    if "Species" in spp.keys():
        check_list.append(spp["Species"])
    gap_spp = next((i for i in gap_lookup if i["scientific_name"] in check_list), None)
    if gap_spp is not None:
        spp["GAP_SpeciesCode"] = gap_spp["GAP_SpeciesCode"]
        spp["GAP_StatesWithHabitat"] = gap_spp["GAP_StatesWithHabitat"]

# %%
[i for i in workplan_species if "GAP_SpeciesCode" in i.keys()]
# Out:
# [{'Guild': 'Amphibians',
#   'Species Name (Common)': 'Cascade torrent salamander',
#   'Scientific Name': 'Rhyacotriton cascadae',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'OR, WA',
#   'Bin': None,
#   'Lookup Name': 'Rhyacotriton cascadae',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/1375',
#   'ITIS TSN': '550250',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Rhyacotritonidae',
#   'Genus': 'Rhyacotriton',
#   'Species': 'Rhyacotriton cascadae',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D03E',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59435A11941314.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102976',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Oregon,Washington',
#   'sgcn_statelist_2015': 'Oregon,Washington',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2431178',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 600,
#   'GAP_SpeciesCode': 'aCTRSx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Cascades frog',
#   'Scientific Name': 'Rana cascadae',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2022,
#   'Range': 'OR, WA',
#   'Bin': None,
#   'Lookup Name': 'Rana cascadae',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/7827',
#   'ITIS TSN': '173450',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Anura',
#   'Family': 'Ranidae',
#   'Genus': 'Rana',
#   'Species': 'Rana cascadae',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D02E',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T19176A8847565.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103017',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Oregon',
#   'sgcn_statelist_2015': 'California,Oregon',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2426771',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 3004,
#   'GAP_SpeciesCode': 'aCSFRx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Columbia torrent salamander',
#   'Scientific Name': 'Rhyacotriton kezeri',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'OR, WA',
#   'Bin': None,
#   'Lookup Name': 'Rhyacotriton kezeri',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/3376',
#   'ITIS TSN': '550251',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Rhyacotritonidae',
#   'Genus': 'Rhyacotriton',
#   'Species': 'Rhyacotriton kezeri',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D03M',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59436A11941421.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Stable',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103633',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Oregon,Washington',
#   'sgcn_statelist_2015': 'Oregon,Washington',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2431179',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 857,
#   'GAP_SpeciesCode': 'aCTOSx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'northern spotted owl',
#   'Scientific Name': 'Strix occidentalis caurina',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2017,
#   'Range': 'CA, OR, WA',
#   'Bin': None,
#   'Lookup Name': 'Strix occidentalis caurina',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/1123',
#   'ITIS TSN': '177926',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Subspecies',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Strigiformes',
#   'Family': 'Strigidae',
#   'Subfamily': 'Striginae',
#   'Genus': 'Strix',
#   'Species': 'Strix occidentalis',
#   'Subspecies': 'Strix occidentalis caurina',
#   'STATUS': 'T',
#   'STATUS_TEXT': 'Threatened',
#   'ECOS_SPCODE': 'B08B',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.104619',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Oregon,Washington',
#   'sgcn_statelist_2015': 'California,Oregon,Washington',
#   'gbif_reference': 'http://api.gbif.org/v1/species/6176043',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 4169,
#   'sb_reference': 'https://www.sciencebase.gov/catalog/items?q=Strix+occidentalis+caurina&max=1000&filter0=systemType%3DData+Release&fields=title%2Cbody%2Ccontacts%2Cdates%2CwebLinks%2Cfiles',
#   'sb_number_items': 3,
#   'GAP_SpeciesCode': 'bSPOWc',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'tufted puffin',
#   'Scientific Name': 'Fratercula cirrhata',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'CA, OR, WA',
#   'Bin': None,
#   'Lookup Name': 'Fratercula cirrhata',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/430',
#   'ITIS TSN': '177032',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Charadriiformes',
#   'Family': 'Alcidae',
#   'Genus': 'Fratercula',
#   'Species': 'Fratercula cirrhata',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'B0FO',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T22694934A132582357.en',
#   'iucn_status_code': 'LC',
#   'iucn_status_name': 'Least Concern',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-08-07',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100853',
#   'natureserve_status': 'N5',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Oregon,Washington',
#   'sgcn_statelist_2015': 'Alaska,California,Oregon,Washington',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2481357',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 31172,
#   'GAP_SpeciesCode': 'bTUPUx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California'},
#  {'Guild': 'Mammals',
#   'Species Name (Common)': 'red tree vole',
#   'Scientific Name': 'Arborimus longicaudus',
#   'Lead FWS Regional Office': 'Region 1 - Pacific (Northwest)',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'OR',
#   'Bin': 'LPN 9',
#   'Lookup Name': 'Arborimus longicaudus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp0/profile/speciesProfile?spcode=A0J3',
#   'ITIS TSN': '180353',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Mammalia',
#   'Subclass': 'Theria',
#   'Infraclass': 'Eutheria',
#   'Order': 'Rodentia',
#   'Suborder': 'Myomorpha',
#   'Superfamily': 'Muroidea',
#   'Family': 'Cricetidae',
#   'Subfamily': 'Arvicolinae',
#   'Genus': 'Arborimus',
#   'Species': 'Arborimus longicaudus',
#   'STATUS': 'C',
#   'STATUS_TEXT': 'Candidate',
#   'ECOS_SPCODE': 'A0J3',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-1.RLTS.T42615A22389366.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2016-07-11',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101630',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Oregon',
#   'sgcn_statelist_2015': 'Oregon',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2437931',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 1119,
#   'GAP_SpeciesCode': 'mRTVOx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Arizona toad',
#   'Scientific Name': 'Bufo microscaphus microscaphus',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2022,
#   'Range': 'AZ, CA, NM, NV, UT',
#   'Bin': None,
#   'Lookup Name': 'Bufo microscaphus microscaphus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/2077',
#   'ITIS TSN': '207135',
#   'Valid ITIS Scientific Name': 'Anaxyrus microscaphus',
#   'Valid ITIS TSN': '773525',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Anura',
#   'Family': 'Bufonidae',
#   'Genus': 'Anaxyrus',
#   'Species': 'Anaxyrus microscaphus',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D025',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.105766',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5217046',
#   'gbif_taxonomic_status': 'SYNONYM',
#   'gbif_occurrence_records': 615,
#   'GAP_SpeciesCode': 'aAZTOx',
#   'GAP_StatesWithHabitat': 'California,Nevada,Arizona,Utah,New Mexico'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Blanco blind salamander',
#   'Scientific Name': 'Eurycea robusta',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Eurycea robusta',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/29',
#   'ITIS TSN': '586344',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Eurycea',
#   'Species': 'Eurycea robusta',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D01E',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T39263A10173057.en',
#   'iucn_status_code': 'DD',
#   'iucn_status_name': 'Data Deficient',
#   'iucn_population_trend': 'Unknown',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.104377',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': 'Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5218364',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 2,
#   'GAP_SpeciesCode': 'aBLSAx',
#   'GAP_StatesWithHabitat': 'Texas'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Cascade Caverns salamander',
#   'Scientific Name': 'Eurycea latitans',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Eurycea latitans',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/4624',
#   'ITIS TSN': '208320',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Eurycea',
#   'Species': 'Eurycea latitans',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D012',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59267A11895685.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.106058',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': 'Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5218367',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 130,
#   'GAP_SpeciesCode': 'aCCSAx',
#   'GAP_StatesWithHabitat': 'Texas'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Comal blind salamander',
#   'Scientific Name': 'Eurycea tridentifera',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Eurycea tridentifera',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/2890',
#   'ITIS TSN': '173696',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Eurycea',
#   'Species': 'Eurycea tridentifera',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D00G',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T8393A12909608.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Unknown',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.105210',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': 'Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5218373',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 182,
#   'GAP_SpeciesCode': 'aCBSAx',
#   'GAP_StatesWithHabitat': 'Texas'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Texas salamander',
#   'Scientific Name': 'Eurycea nana',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Eurycea nana',
#   'ECOS Link': 'https://ecos.fws.gov/ecp0/profile/speciesProfile?spcode=D00I',
#   'ITIS TSN': '173693',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Eurycea',
#   'Species': 'Eurycea nana',
#   'STATUS': 'T',
#   'STATUS_TEXT': 'Threatened',
#   'ECOS_SPCODE': 'D00I',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T8391A12909269.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Stable',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.106379',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': 'Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5218369',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 1206,
#   'GAP_SpeciesCode': 'aSMSAx',
#   'GAP_StatesWithHabitat': 'Texas'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'lesser prairie-chicken',
#   'Scientific Name': 'Tympanuchus pallidicinctus',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2017,
#   'Range': 'CO, KS, NM, OK, TX',
#   'Bin': None,
#   'Lookup Name': 'Tympanuchus pallidicinctus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/1924',
#   'ITIS TSN': '175838',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Galliformes',
#   'Family': 'Phasianidae',
#   'Subfamily': 'Tetraoninae',
#   'Genus': 'Tympanuchus',
#   'Species': 'Tympanuchus pallidicinctus',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'B0AZ',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T22679519A131795740.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-08-07',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101816',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Colorado,Kansas,New Mexico,Oklahoma,Texas',
#   'sgcn_statelist_2015': 'Colorado,Kansas,New Mexico,Oklahoma,Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2473529',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 917,
#   'GAP_SpeciesCode': 'bLEPCx',
#   'GAP_StatesWithHabitat': 'New Mexico,Colorado,Texas,Oklahoma,Kansas'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'red-crowned parrot',
#   'Scientific Name': 'Amazona viridigenalis',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'TX, Mexico',
#   'Bin': 'LPN 2',
#   'Lookup Name': 'Amazona viridigenalis',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/9022',
#   'ITIS TSN': '177806',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Psittaciformes',
#   'Family': 'Psittacidae',
#   'Subfamily': 'Psittacinae',
#   'Genus': 'Amazona',
#   'Species': 'Amazona viridigenalis',
#   'STATUS': 'RT',
#   'STATUS_TEXT': 'Resolved Taxon',
#   'ECOS_SPCODE': 'B0GO',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T22686259A131918910.en',
#   'iucn_status_code': 'EN',
#   'iucn_status_name': 'Endangered',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-08-09',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102063',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': 'Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2479665',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 30971,
#   'GAP_SpeciesCode': 'bRCPAx',
#   'GAP_StatesWithHabitat': 'California,Texas,Florida'},
#  {'Guild': 'Mammals',
#   'Species Name (Common)': 'Penasco least chipmunk',
#   'Scientific Name': 'Tamias minimus atristriatus',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'NM',
#   'Bin': 'LPN 6',
#   'Lookup Name': 'Tamias minimus atristriatus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/5126',
#   'ITIS TSN': '632531',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Subspecies',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Mammalia',
#   'Subclass': 'Theria',
#   'Infraclass': 'Eutheria',
#   'Order': 'Rodentia',
#   'Suborder': 'Sciuromorpha',
#   'Family': 'Sciuridae',
#   'Subfamily': 'Xerinae',
#   'Tribe': 'Marmotini',
#   'Genus': 'Tamias',
#   'Subgenus': 'Tamias (Neotamias)',
#   'Species': 'Tamias minimus',
#   'Subspecies': 'Tamias minimus atristriatus',
#   'STATUS': 'C',
#   'STATUS_TEXT': 'Candidate',
#   'ECOS_SPCODE': 'A08G',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102143',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': '',
#   'sgcn_statelist_2015': 'New Mexico',
#   'gbif_reference': 'http://api.gbif.org/v1/species/6163579',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 11,
#   'GAP_SpeciesCode': 'mLECHt',
#   'GAP_StatesWithHabitat': 'New Mexico'},
#  {'Guild': 'Mammals',
#   'Species Name (Common)': 'Texas kangaroo rat',
#   'Scientific Name': 'Dipodomys elator',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2020,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Dipodomys elator',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/2985',
#   'ITIS TSN': '180237',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Mammalia',
#   'Subclass': 'Theria',
#   'Infraclass': 'Eutheria',
#   'Order': 'Rodentia',
#   'Suborder': 'Castorimorpha',
#   'Family': 'Heteromyidae',
#   'Subfamily': 'Dipodomyinae',
#   'Genus': 'Dipodomys',
#   'Species': 'Dipodomys elator',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'A08R',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-1.RLTS.T6675A22227507.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2016-07-11',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101748',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Oklahoma,Texas',
#   'sgcn_statelist_2015': 'Oklahoma,Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2439549',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 415,
#   'GAP_SpeciesCode': 'mTKRAx',
#   'GAP_StatesWithHabitat': 'Texas,Oklahoma'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'Arizona striped whiptail',
#   'Scientific Name': 'aspidoscelis arizonae',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'AZ',
#   'Bin': None,
#   'Lookup Name': 'Aspidoscelis arizonae',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/8793',
#   'ITIS TSN': None,
#   'Valid ITIS Scientific Name': 'Cnemidophorus inornatus arizonae',
#   'Valid ITIS TSN': '208930',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Subspecies',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Squamata',
#   'Suborder': 'Autarchoglossa',
#   'Family': 'Teiidae',
#   'Genus': 'Cnemidophorus',
#   'Species': 'Cnemidophorus inornatus',
#   'Subspecies': 'Cnemidophorus inornatus arizonae',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.106205',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5789647',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 230,
#   'GAP_SpeciesCode': 'rASWHx',
#   'GAP_StatesWithHabitat': 'Arizona'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'Rio Grande cooter',
#   'Scientific Name': 'Pseudemys gorzugi',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'NM, TX',
#   'Bin': None,
#   'Lookup Name': 'Pseudemys gorzugi',
#   'ECOS Link': None,
#   'ITIS TSN': None,
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Testudines',
#   'Suborder': 'Cryptodira',
#   'Superfamily': 'Testudinoidea',
#   'Family': 'Emydidae',
#   'Subfamily': 'Deirochelyinae',
#   'Genus': 'Pseudemys',
#   'Species': 'Pseudemys gorzugi',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C079',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2011-1.RLTS.T18459A8297596.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Unknown',
#   'iucn_record_date': '2010-08-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103473',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'New Mexico,Texas',
#   'sgcn_statelist_2015': 'New Mexico,Texas',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2442831',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 161,
#   'sb_reference': 'https://www.sciencebase.gov/catalog/items?q=Pseudemys+gorzugi&max=1000&filter0=systemType%3DData+Release&fields=title%2Cbody%2Ccontacts%2Cdates%2CwebLinks%2Cfiles',
#   'sb_number_items': 1,
#   'GAP_SpeciesCode': 'rRGCOx',
#   'GAP_StatesWithHabitat': 'New Mexico,Texas'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'spot-tailed earless lizard',
#   'Scientific Name': 'Holbrookia lacerata',
#   'Lead FWS Regional Office': 'Region 2 - Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2020,
#   'Range': 'TX',
#   'Bin': None,
#   'Lookup Name': 'Holbrookia lacerata',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/9044',
#   'ITIS TSN': '173926',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Squamata',
#   'Suborder': 'Iguania',
#   'Family': 'Phrynosomatidae',
#   'Subfamily': 'Phrynosomatinae',
#   'Genus': 'Holbrookia',
#   'Species': 'Holbrookia lacerata',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C073',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2007.RLTS.T64064A12733280.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2007-03-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103768',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Texas',
#   'sgcn_statelist_2015': '',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2451451',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 689,
#   'GAP_SpeciesCode': 'rSTELx',
#   'GAP_StatesWithHabitat': 'New Mexico,Texas'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'hellbender',
#   'Scientific Name': 'Cryptobranchus alleganiensis',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'AL, AR, GA, IL, IN, KY, MD, MO, MS, NC, NY, OH, PA, SC, TN, VA, WV',
#   'Bin': None,
#   'Lookup Name': 'Cryptobranchus alleganiensis',
#   'ECOS Link': 'https://ecos.fws.gov/ecp0/profile/speciesProfile?spcode=D00Y',
#   'ITIS TSN': '173587',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Cryptobranchidae',
#   'Genus': 'Cryptobranchus',
#   'Species': 'Cryptobranchus alleganiensis',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D00Y',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59077A11879843.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.105670',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Alabama,Georgia,Illinois,Indiana,Maryland,Mississippi,New York,Ohio,Pennsylvania,South Carolina,Tennessee,Virginia,West Virginia',
#   'sgcn_statelist_2015': 'Georgia,Illinois,Indiana,Maryland,Mississippi,New York,Ohio,Tennessee,West Virginia',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2432031',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 2159,
#   'GAP_SpeciesCode': 'aHELLx',
#   'GAP_StatesWithHabitat': 'Missouri,Arkansas,Mississippi,Illinois,Alabama,Indiana,Tennessee,Kentucky,Georgia,Ohio,West Virginia,North Carolina,Virginia,Pennsylvania,Maryland,New York,Delaware'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Illinois chorus frog',
#   'Scientific Name': 'Pseudacris illinoensis',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'AR, IL, MO',
#   'Bin': None,
#   'Lookup Name': 'Pseudacris illinoensis',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/455',
#   'ITIS TSN': '662726',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Anura',
#   'Family': 'Hylidae',
#   'Subfamily': 'Hylinae',
#   'Genus': 'Pseudacris',
#   'Species': 'Pseudacris illinoensis',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D00U',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.869802',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Arkansas,Illinois,Missouri',
#   'sgcn_statelist_2015': 'Arkansas,Illinois,Missouri',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2428134',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 1004,
#   'GAP_SpeciesCode': 'aILGRx',
#   'GAP_StatesWithHabitat': 'Missouri,Arkansas,Illinois,Tennessee,Kentucky'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'golden-winged warbler',
#   'Scientific Name': 'Vermivora chrysoptera',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'AL, AR, CO, CT, DC, DE, FL, GA, IA, IL, IN, KS, KY, LA, MA, MD, MI, MN, MO, MS, NC, ND, NE, NH, NJ, NY, OH, OK, PA, SC, SD, TN, TX, VA, VT, WI, WV',
#   'Bin': None,
#   'Lookup Name': 'Vermivora chrysoptera',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/8745',
#   'ITIS TSN': '178852',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Passeriformes',
#   'Family': 'Parulidae',
#   'Genus': 'Vermivora',
#   'Species': 'Vermivora chrysoptera',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'B0G4',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T22721618A132145282.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-08-09',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102068',
#   'natureserve_status': 'N4B',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Connecticut,Delaware,Georgia,Indiana,Iowa,Kentucky,Maryland,Massachusetts,Michigan,Minnesota,New Hampshire,New Jersey,New York,North Carolina,Ohio,Pennsylvania,Tennessee,Texas,Vermont,Virginia,West Virginia,Wisconsin',
#   'sgcn_statelist_2015': 'Connecticut,Delaware,District of Columbia,Florida,Georgia,Illinois,Indiana,Iowa,Kentucky,Louisiana,Maryland,Massachusetts,Michigan,Minnesota,New Hampshire,New Jersey,New York,North Carolina,Oklahoma,Pennsylvania,South Carolina,Tennessee,Vermont,Virginia,West Virginia,Wisconsin',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5230811',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 66196,
#   'GAP_SpeciesCode': 'bGWWAx',
#   'GAP_StatesWithHabitat': 'North Dakota,Minnesota,Missouri,Wisconsin,Illinois,Indiana,Michigan,Tennessee,Kentucky,Georgia,Ohio,South Carolina,West Virginia,North Carolina,Virginia,Pennsylvania,Maryland,District of Columbia,New York,New Jersey,Connecticut,Vermont,Massachusetts,New Hampshire,Rhode Island'},
#  {'Guild': 'Mammals',
#   'Species Name (Common)': 'little brown bat',
#   'Scientific Name': 'Myotis lucifugus',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'AK, AL, AR, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, UT, VA, VT, WA, WI, WV, WY',
#   'Bin': None,
#   'Lookup Name': 'Myotis lucifugus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/9051',
#   'ITIS TSN': '179988',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Mammalia',
#   'Subclass': 'Theria',
#   'Infraclass': 'Eutheria',
#   'Order': 'Chiroptera',
#   'Suborder': 'Yangochiroptera',
#   'Superfamily': 'Vespertilionoidea',
#   'Family': 'Vespertilionidae',
#   'Subfamily': 'Myotinae',
#   'Genus': 'Myotis',
#   'Species': 'Myotis lucifugus',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'A0JF',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T14176A22056344.en',
#   'iucn_status_code': 'EN',
#   'iucn_status_name': 'Endangered',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-02-09',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100473',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Alabama,Alaska,California,Connecticut,Indiana,Kansas,Mississippi,Nevada,Ohio,Rhode Island,Vermont,Wyoming',
#   'sgcn_statelist_2015': 'Alabama,Alaska,Arkansas,Colorado,Connecticut,Delaware,District of Columbia,Georgia,Idaho,Indiana,Iowa,Kansas,Maine,Maryland,Massachusetts,Michigan,Minnesota,Mississippi,Nebraska,Nevada,New Hampshire,New Jersey,New York,North Carolina,North Dakota,Ohio,Pennsylvania,Rhode Island,South Carolina,Tennessee,Texas,Utah,Vermont,Virginia,West Virginia,Wisconsin,Wyoming',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2432406',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 15245,
#   'sb_reference': 'https://www.sciencebase.gov/catalog/items?q=Myotis+lucifugus&max=1000&filter0=systemType%3DData+Release&fields=title%2Cbody%2Ccontacts%2Cdates%2CwebLinks%2Cfiles',
#   'sb_number_items': 2,
#   'GAP_SpeciesCode': 'mLBMYx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California,Nevada,Idaho,Arizona,Utah,Montana,Wyoming,New Mexico,Colorado,North Dakota,South Dakota,Texas,Nebraska,Oklahoma,Kansas,Iowa,Minnesota,Missouri,Arkansas,Louisiana,Mississippi,Wisconsin,Illinois,Alabama,Indiana,Michigan,Tennessee,Kentucky,Florida,Georgia,Ohio,South Carolina,West Virginia,North Carolina,Virginia,Pennsylvania,Maryland,District of Columbia,New York,Delaware,New Jersey,Connecticut,Vermont,Massachusetts,New Hampshire,Rhode Island,Maine'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': "Blanding's turtle",
#   'Scientific Name': 'Emydoidea blandingii',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'IA, IL, IN, MA, ME, MI, MN, MO, NE, NH, NY, OH, PA, SD, WI',
#   'Bin': None,
#   'Lookup Name': 'Emydoidea blandingii',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/6056',
#   'ITIS TSN': '173789',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Testudines',
#   'Suborder': 'Cryptodira',
#   'Superfamily': 'Testudinoidea',
#   'Family': 'Emydidae',
#   'Subfamily': 'Emydinae',
#   'Genus': 'Emydoidea',
#   'Species': 'Emydoidea blandingii',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C05M',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2011-1.RLTS.T7709A12843518.en',
#   'iucn_status_code': 'EN',
#   'iucn_status_name': 'Endangered',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2010-08-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100408',
#   'natureserve_status': 'N4',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Illinois,Indiana,Iowa,Maine,Massachusetts,Michigan,Minnesota,Missouri,Nebraska,New Hampshire,New York,Ohio,Pennsylvania,South Dakota,Wisconsin',
#   'sgcn_statelist_2015': 'Illinois,Indiana,Iowa,Maine,Massachusetts,Michigan,Minnesota,Missouri,Nebraska,New Hampshire,New York,Ohio,Pennsylvania,Wisconsin',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2442885',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 5117,
#   'GAP_SpeciesCode': 'rBTURx',
#   'GAP_StatesWithHabitat': 'South Dakota,Nebraska,Iowa,Minnesota,Missouri,Wisconsin,Illinois,Indiana,Michigan,Ohio,Pennsylvania,New York,Connecticut,Massachusetts,New Hampshire,Rhode Island,Maine'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': "Kirtland's snake",
#   'Scientific Name': 'Clonophis kirtlandii',
#   'Lead FWS Regional Office': 'Region 3 - Midwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2017,
#   'Range': 'IL, IN, KY, MI, MO, OH, PA, TN',
#   'Bin': None,
#   'Lookup Name': 'Clonophis kirtlandii',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/4979',
#   'ITIS TSN': '174216',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Squamata',
#   'Suborder': 'Serpentes',
#   'Infraorder': 'Alethinophidia',
#   'Family': 'Colubridae',
#   'Subfamily': 'Natricinae',
#   'Genus': 'Clonophis',
#   'Species': 'Clonophis kirtlandii',
#   'STATUS': 'RT',
#   'STATUS_TEXT': 'Resolved Taxon',
#   'ECOS_SPCODE': 'C041',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2007.RLTS.T63747A12712865.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2007-03-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.105161',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Illinois,Indiana,Kentucky,Michigan,Missouri,Ohio,Pennsylvania',
#   'sgcn_statelist_2015': 'Illinois,Indiana,Kentucky,Michigan,Missouri,Ohio,Pennsylvania,Tennessee',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2456368',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 636,
#   'GAP_SpeciesCode': 'rKISNx',
#   'GAP_StatesWithHabitat': 'Missouri,Wisconsin,Illinois,Indiana,Michigan,Kentucky,Ohio,Pennsylvania'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Berry Cave Salamander',
#   'Scientific Name': 'Gyrinophilus gulolineatus',
#   'Lead FWS Regional Office': 'Region 4 - Southeast',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'TN',
#   'Bin': 'LPN 8',
#   'Lookup Name': 'Gyrinophilus gulolineatus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/4043',
#   'ITIS TSN': '550249',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Gyrinophilus',
#   'Species': 'Gyrinophilus gulolineatus',
#   'STATUS': 'C',
#   'STATUS_TEXT': 'Candidate',
#   'ECOS_SPCODE': 'D03B',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59280A11896479.en',
#   'iucn_status_code': 'EN',
#   'iucn_status_name': 'Endangered',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.104271',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Tennessee',
#   'sgcn_statelist_2015': 'Tennessee',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2431433',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 42,
#   'GAP_SpeciesCode': 'aBCSAx',
#   'GAP_StatesWithHabitat': 'Tennessee'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Georgia blind salamander',
#   'Scientific Name': 'Haideotriton wallacei',
#   'Lead FWS Regional Office': 'Region 4 - Southeast',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2023,
#   'Range': 'FL, GA',
#   'Bin': None,
#   'Lookup Name': 'Haideotriton wallacei',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/8465',
#   'ITIS TSN': '173717',
#   'Valid ITIS Scientific Name': 'Eurycea wallacei',
#   'Valid ITIS TSN': '775913',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Spelerpinae',
#   'Genus': 'Eurycea',
#   'Species': 'Eurycea wallacei',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D016',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101825',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2431560',
#   'gbif_taxonomic_status': 'SYNONYM',
#   'gbif_occurrence_records': 86,
#   'GAP_SpeciesCode': 'aGBSAx',
#   'GAP_StatesWithHabitat': 'Alabama,Florida,Georgia'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Neuse River waterdog',
#   'Scientific Name': 'Necturus lewisi',
#   'Lead FWS Regional Office': 'Region 4 - Southeast',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2017,
#   'Range': 'NC',
#   'Bin': None,
#   'Lookup Name': 'Necturus lewisi',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/6772',
#   'ITIS TSN': '173627',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Proteidae',
#   'Genus': 'Necturus',
#   'Species': 'Necturus lewisi',
#   'STATUS': 'PT',
#   'STATUS_TEXT': 'Proposed Threatened',
#   'ECOS_SPCODE': 'D00O',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59432A11940982.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100341',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'North Carolina',
#   'sgcn_statelist_2015': 'North Carolina',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2432046',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 175,
#   'GAP_SpeciesCode': 'aNRWAx',
#   'GAP_StatesWithHabitat': 'North Carolina,Virginia'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'Oklahoma salamander',
#   'Scientific Name': 'Eurycea tynerensis',
#   'Lead FWS Regional Office': 'Region 4 - Southeast',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2020,
#   'Range': 'OK, MO, AR',
#   'Bin': None,
#   'Lookup Name': 'Eurycea tynerensis',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/4096',
#   'ITIS TSN': '173697',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
# ...
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/6607',
#   'ITIS TSN': '173721',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Caudata',
#   'Family': 'Plethodontidae',
#   'Subfamily': 'Plethodontinae',
#   'Genus': 'Hydromantes',
#   'Species': 'Hydromantes shastae',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D01I',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T10305A3192713.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Stable',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103280',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California',
#   'sgcn_statelist_2015': 'California',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2431663',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 277,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Hydromantes shastae',
#   'xdd_number_docs': 6,
#   'GAP_SpeciesCode': 'aSHSAx',
#   'GAP_StatesWithHabitat': 'California'},
#  {'Guild': 'Amphibians',
#   'Species Name (Common)': 'western spadefoot',
#   'Scientific Name': 'Spea hammondii',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2020,
#   'Range': 'CA',
#   'Bin': None,
#   'Lookup Name': 'Spea hammondii',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/5425',
#   'ITIS TSN': '206990',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Amphibia',
#   'Order': 'Anura',
#   'Family': 'Scaphiopodidae',
#   'Genus': 'Spea',
#   'Species': 'Spea hammondii',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'D02Z',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2004.RLTS.T59045A11874606.en',
#   'iucn_status_code': 'NT',
#   'iucn_status_name': 'Near Threatened',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2004-04-30',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100387',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California',
#   'sgcn_statelist_2015': 'California',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2429783',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 2674,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Spea hammondii',
#   'xdd_number_docs': 81,
#   'GAP_SpeciesCode': 'aWESPx',
#   'GAP_StatesWithHabitat': 'California'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'black-backed woodpecker (Oregon Cascades-California population)',
#   'Scientific Name': 'picoides arcticus',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2017,
#   'Range': 'CA, ND, OR',
#   'Bin': None,
#   'Lookup Name': 'Picoides arcticus',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/7951',
#   'ITIS TSN': '178250',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Piciformes',
#   'Family': 'Picidae',
#   'Subfamily': 'Picinae',
#   'Genus': 'Picoides',
#   'Species': 'Picoides arcticus',
#   'STATUS': 'RT',
#   'STATUS_TEXT': 'Resolved Taxon',
#   'ECOS_SPCODE': 'B0F5',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2016-3.RLTS.T22681181A92895828.en',
#   'iucn_status_code': 'LC',
#   'iucn_status_name': 'Least Concern',
#   'iucn_population_trend': 'Stable',
#   'iucn_record_date': '2016-10-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102076',
#   'natureserve_status': 'N4',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'Alaska,Michigan,Minnesota,Montana,Oregon,South Dakota,Vermont,Washington,Wisconsin,Wyoming',
#   'sgcn_statelist_2015': 'Alaska,Maine,Michigan,Minnesota,Oregon,South Dakota,Vermont,Wisconsin,Wyoming',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2477774',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 18988,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Picoides arcticus',
#   'xdd_number_docs': 225,
#   'GAP_SpeciesCode': 'bBBWOx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California,Nevada,Idaho,Montana,Wyoming,North Dakota,Minnesota,Wisconsin,Michigan,New York,Vermont,New Hampshire,Maine'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'California spotted owl',
#   'Scientific Name': 'Strix occidentalis occidentalis',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'CA, OR',
#   'Bin': None,
#   'Lookup Name': 'Strix occidentalis occidentalis',
#   'ECOS Link': None,
#   'ITIS TSN': None,
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Subspecies',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Strigiformes',
#   'Family': 'Strigidae',
#   'Subfamily': 'Striginae',
#   'Genus': 'Strix',
#   'Species': 'Strix occidentalis',
#   'Subspecies': 'Strix occidentalis occidentalis',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'B08L',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103028',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Nevada',
#   'sgcn_statelist_2015': 'California,Nevada',
#   'gbif_reference': 'http://api.gbif.org/v1/species/7191276',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 199,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Strix occidentalis occidentalis',
#   'xdd_number_docs': 146,
#   'sb_reference': 'https://www.sciencebase.gov/catalog/items?q=Strix+occidentalis+occidentalis&max=1000&filter0=systemType%3DData+Release&fields=title%2Cbody%2Ccontacts%2Cdates%2CwebLinks%2Cfiles',
#   'sb_number_items': 3,
#   'GAP_SpeciesCode': 'bSPOWo',
#   'GAP_StatesWithHabitat': 'California,Nevada'},
#  {'Guild': 'Birds',
#   'Species Name (Common)': 'tricolor blackbird',
#   'Scientific Name': 'Agelaius tricolor',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'CA, OR, WA, NV',
#   'Bin': None,
#   'Lookup Name': 'Agelaius tricolor',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/3910',
#   'ITIS TSN': '179060',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Aves',
#   'Order': 'Passeriformes',
#   'Family': 'Icteridae',
#   'Genus': 'Agelaius',
#   'Species': 'Agelaius tricolor',
#   'STATUS': 'RT',
#   'STATUS_TEXT': 'Resolved Taxon',
#   'ECOS_SPCODE': 'B06P',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2018-2.RLTS.T22724196A132028149.en',
#   'iucn_status_code': 'EN',
#   'iucn_status_name': 'Endangered',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2018-08-09',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101015',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Nevada',
#   'sgcn_statelist_2015': 'California,Nevada',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2484445',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 48730,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Agelaius tricolor',
#   'xdd_number_docs': 66,
#   'GAP_SpeciesCode': 'bTRBLx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California,Nevada'},
#  {'Guild': 'Mammals',
#   'Species Name (Common)': 'Sierra Nevada red fox',
#   'Scientific Name': 'Vulpes vulpes necator',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'CA, OR',
#   'Bin': 'LPN 3',
#   'Lookup Name': 'Vulpes vulpes necator',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/4252',
#   'ITIS TSN': '726953',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Subspecies',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Mammalia',
#   'Subclass': 'Theria',
#   'Infraclass': 'Eutheria',
#   'Order': 'Carnivora',
#   'Suborder': 'Caniformia',
#   'Family': 'Canidae',
#   'Genus': 'Vulpes',
#   'Species': 'Vulpes vulpes',
#   'Subspecies': 'Vulpes vulpes necator',
#   'STATUS': 'RT,C',
#   'STATUS_TEXT': 'Candidate,Resolved Taxon',
#   'ECOS_SPCODE': 'A0AY',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103277',
#   'natureserve_status': 'N1',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Nevada',
#   'sgcn_statelist_2015': 'California,Oregon',
#   'gbif_reference': 'http://api.gbif.org/v1/species/6164287',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 300,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Vulpes vulpes necator',
#   'xdd_number_docs': 7,
#   'GAP_SpeciesCode': 'mREFOn',
#   'GAP_StatesWithHabitat': 'Oregon,California,Nevada'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'Panamint alligator lizard',
#   'Scientific Name': 'Elgaria panamintina',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2018,
#   'Range': 'CA',
#   'Bin': None,
#   'Lookup Name': 'Elgaria panamintina',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/47',
#   'ITIS TSN': '209029',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Squamata',
#   'Suborder': 'Autarchoglossa',
#   'Family': 'Anguidae',
#   'Genus': 'Elgaria',
#   'Species': 'Elgaria panamintina',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C05V',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.2007.RLTS.T40792A10355592.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': 'Decreasing',
#   'iucn_record_date': '2007-03-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100264',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Nevada',
#   'sgcn_statelist_2015': 'California,Nevada',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2468282',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 105,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Elgaria panamintina',
#   'xdd_number_docs': 11,
#   'GAP_SpeciesCode': 'rPALIx',
#   'GAP_StatesWithHabitat': 'California,Nevada'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'southern rubber boa',
#   'Scientific Name': 'Charina bottae umbratica',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2019,
#   'Range': 'CA',
#   'Bin': None,
#   'Lookup Name': 'Charina bottae umbratica',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/3525',
#   'ITIS TSN': '209559',
#   'Valid ITIS Scientific Name': 'Charina umbratica',
#   'Valid ITIS TSN': '683027',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Squamata',
#   'Suborder': 'Serpentes',
#   'Infraorder': 'Alethinophidia',
#   'Family': 'Charinidae',
#   'Subfamily': 'Charininae',
#   'Genus': 'Charina',
#   'Species': 'Charina umbratica',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C03B',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101155',
#   'natureserve_status': 'N2',
#   'natureserve_last_review_date': 'unknown',
#   'gbif_reference': 'http://api.gbif.org/v1/species/5225699',
#   'gbif_taxonomic_status': 'SYNONYM',
#   'gbif_occurrence_records': 2,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Charina bottae umbratica',
#   'xdd_number_docs': 1,
#   'GAP_SpeciesCode': 'rSRBOx',
#   'GAP_StatesWithHabitat': 'California'},
#  {'Guild': 'Reptiles',
#   'Species Name (Common)': 'western pond turtle',
#   'Scientific Name': 'Actinemys marmorata',
#   'Lead FWS Regional Office': 'Region 8 - Pacific Southwest',
#   'Proposed FWS Decision Timeframe (Fiscal Year)': 2021,
#   'Range': 'CA, OR, WA, Mexico',
#   'Bin': None,
#   'Lookup Name': 'Actinemys marmorata',
#   'ECOS Link': 'https://ecos.fws.gov/ecp/species/1833',
#   'ITIS TSN': '668668',
#   'taxonomic_reference': 'ITIS',
#   'taxonomic_rank': 'Species',
#   'Kingdom': 'Animalia',
#   'Subkingdom': 'Bilateria',
#   'Infrakingdom': 'Deuterostomia',
#   'Phylum': 'Chordata',
#   'Subphylum': 'Vertebrata',
#   'Infraphylum': 'Gnathostomata',
#   'Superclass': 'Tetrapoda',
#   'Class': 'Reptilia',
#   'Order': 'Testudines',
#   'Suborder': 'Cryptodira',
#   'Superfamily': 'Testudinoidea',
#   'Family': 'Emydidae',
#   'Subfamily': 'Emydinae',
#   'Genus': 'Actinemys',
#   'Species': 'Actinemys marmorata',
#   'STATUS': 'UR',
#   'STATUS_TEXT': 'Under Review in the Candidate or Petition Process',
#   'ECOS_SPCODE': 'C06B',
#   'iucn_reference': 'http://dx.doi.org/10.2305/IUCN.UK.1996.RLTS.T4969A11104202.en',
#   'iucn_status_code': 'VU',
#   'iucn_status_name': 'Vulnerable',
#   'iucn_population_trend': None,
#   'iucn_record_date': '1996-08-01',
#   'natureserve_reference': 'http://explorer.natureserve.org/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102191',
#   'natureserve_status': 'N3',
#   'natureserve_last_review_date': 'unknown',
#   'sgcn_statelist_2005': 'California,Nevada,Washington',
#   'sgcn_statelist_2015': 'California,Nevada,Oregon,Washington',
#   'gbif_reference': 'http://api.gbif.org/v1/species/2442896',
#   'gbif_taxonomic_status': 'ACCEPTED',
#   'gbif_occurrence_records': 4583,
#   'xdd_reference': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Actinemys marmorata',
#   'xdd_number_docs': 50,
#   'sb_reference': 'https://www.sciencebase.gov/catalog/items?q=Actinemys+marmorata&max=1000&filter0=systemType%3DData+Release&fields=title%2Cbody%2Ccontacts%2Cdates%2CwebLinks%2Cfiles',
#   'sb_number_items': 1,
#   'GAP_SpeciesCode': 'rWPTUx',
#   'GAP_StatesWithHabitat': 'Washington,Oregon,California,Nevada'}]

# %%
df_wp_spp = pd.DataFrame(workplan_species).to_csv('../cache/summarized_data.csv', index=False)
