# %% [markdown]
# This notebook works over the Excel spreadsheet of FWS ESA Work Plan Species to put the data into our working Biogeographic Information System database (currently a MongoDB database). That turns the records into a form that we can process through the Taxa Information Registry to assemble attributes for further analysis and reporting. The spreadseet in Excel format was put together by USGS Ecosystems personnel. FWS has this list on a [web site](https://www.fws.gov/endangered/what-we-do/listing-workplan.html) and in a [PDF document](https://www.fws.gov/endangered/esa-library/pdf/Listing%207-Year%20Workplan%20Sept%202016.pdf) with some additional information.

# %%
import pandas as pd
from bis2 import dd
from IPython.display import display
from datetime import datetime

# %% [markdown]
# A couple of new functions to move into the BIS somewhere.

# %%
def packageESASpeciesRow(row):
    submittedData = {}
    submittedData["Scientific Name"] = row["Scientific Name (Revised List)"]
    submittedData["Species Record Reference"] = row["ScientificNameLink"] 
    submittedData["Common Name"] = row["Species Name (Common)"]
    submittedData["Grouping"] = row["Grouping"]
    submittedData["Lead FWS Region"] = row["Lead FWS Regional Office"]
    submittedData["Species Range"] = row["Species Range"]
    return submittedData

def lookupState(stateAbbr):
    import us
    try:
        return {"name":us.states.mapping('abbr', 'name')[stateAbbr],"fips":us.states.mapping('abbr', 'fips')[stateAbbr]}
    except:
        return None

# %% [markdown]
# Read the spreadsheet from the Excel file into a Pandas dataframe. I extracted out the ECOS link from the hyperlink on scientific name into its own attribute but kept the spreadsheet intact otherwise.

# %%
df = pd.read_excel("FWS ESA Work Plan Species list for CSS.xlsx", sheet_name='Sheet1')
display (df)
# Out:
#        Grouping              Species Name (Common)  \
# 0    Amphibians              streamside salamander
# 1    Amphibians   Boreal toad (Eastern population)
# 2    Amphibians  Inyo Mountains slender salamander
# 3    Amphibians          lesser slender salamander
# 4    Amphibians       relictual slender salamander
# 5    Amphibians            Kern Plateau salamander
# 6    Amphibians     Kern Canyon slender salamander
# 7    Amphibians          Oregon slender salamander
# 8    Amphibians                       Arizona toad
# 9    Amphibians                         hellbender
# 10   Amphibians         Cascade Caverns salamander
# 11   Amphibians                   Texas salamander
# 12   Amphibians            Blanco blind salamander
# 13   Amphibians           Comal Springs salamander
# 14   Amphibians             Comal blind salamander
# 15   Amphibians                Oklahoma salamander
# 16   Amphibians              Berry Cave Salamander
# 17   Amphibians          Tennessee Cave salamander
# 18   Amphibians    West Virginia spring salamander
# 19   Amphibians           Georgia blind salamander
# 20   Amphibians               limestone salamander
# 21   Amphibians                  Shasta salamander
# 22   Amphibians               Neuse River waterdog
# 23   Amphibians                       striped newt
# 24   Amphibians          Peaks of Otter salamander
# 25   Amphibians               Illinois chorus frog
# 26   Amphibians        foothill yellow-legged frog
# 27   Amphibians                      Cascades frog
# 28   Amphibians         Cascade torrent salamander
# 29   Amphibians        Columbia torrent salamander
# ..          ...                                ...
# 333      Snails                   Butterfield pyrg
# 334      Snails                         Hardy pyrg
# 335      Snails             Pahranagat pebblesnail
# 336      Snails           distal-gland springsnail
# 337      Snails      neritiform Steptoe Ranch pyrg
# 338      Snails     sub-globose Steptoe Ranch pyrg
# 339      Snails                         Ozark pyrg
# 340      Snails                    bifid duct pyrg
# 341      Snails           median-gland Nevada pyrg
# 342      Snails           flat-topped Steptoe pyrg
# 343      Snails            White River Valley pyrg
# 344      Snails             sub-globose snake pyrg
# 345      Snails              northern Steptoe pyrg
# 346      Snails                 Sterile Basin pyrg
# 347      Snails                   Lake Valley pyrg
# 348      Snails              southern Steptoe pyrg
# 349      Snails              Southeast Nevada pyrg
# 350      Snails              San Xavier talussnail
# 351      Snails                Pinaleno talussnail
# 352      Snails              Wet Canyon talussnail
# 353      Snails                   Shasta chaparral
# 354      Snails              sportinggoods tryonia
# 355      Snails                     grated tryonia
# 356      Snails             Point of Rocks tryonia
# 357      Snails                     minute tryonia
# 358      Snails               Quitobaquito tryonia
# 359      Snails                   Amargosa tryonia
# 360      Snails                       Hoko vertigo
# 361      Snails                  Big Bar hesperian
# 362      Snails                   Shasta hesperian
#
#                     Scientific Name (Revised List) Lead FWS Regional Office  \
# 0                               Ambystoma barbouri                       R4
# 1                           Anaxyrus boreas boreas                       R6
# 2                               Batrachoseps campi                       R8
# 3                               Batrachoseps minor                       R8
# 4                            Batrachoseps relictus                       R8
# 5                            Batrachoseps robustus                       R8
# 6                             Batrachoseps simatus                       R8
# 7                             Batrachoseps wrighti                       R1
# 8                   Bufo microscaphus microscaphus                       R2
# 9                     Cryptobranchus alleganiensis                       R3
# 10                                Eurycea latitans                       R2
# 11                                    Eurycea nana                       R2
# 12                                 Eurycea robusta                       R2
# 13                                     Eurycea sp.                       R2
# 14                            Eurycea tridentifera                       R2
# 15                              Eurycea tynerensis                       R4
# 16                       Gyrinophilus gulolineatus                       R4
# 17                          Gyrinophilus palleucus                       R4
# 18                       Gyrinophilus subterraneus                       R5
# 19                           Haideotriton wallacei                       R4
# 20                              Hydromantes brunus                       R8
# 21                             Hydromantes shastae                       R8
# 22                                 Necturus lewisi                       R4
# 23                       Notophthalmus perstriatus                       R4
# 24                             Plethodon hubrichti                       R5
# 25                          Pseudacris illinoensis                       R3
# 26                                     Rana boylii                       R8
# 27                                   Rana cascadae                       R1
# 28                           Rhyacotriton cascadae                       R1
# 29                             Rhyacotriton kezeri                       R1
# ..                                             ...                      ...
# 333                               Pyrgulopsis lata                       R8
# 334                            Pyrgulopsis marcida                       R8
# 335                           Pyrgulopsis merriami                       R8
# 336                              Pyrgulopsis nanus                       R8
# 337                          Pyrgulopsis neritella                       R8
# 338                         Pyrgulopsis orbiculata                       R8
# 339  Pyrgulopsis ozarkensis (Marstonia ozarkensis)                       R4
# 340                         Pyrgulopsis peculiaris                       R8
# 341                            Pyrgulopsis pisteri                       R8
# 342                          Pyrgulopsis planulata                       R8
# 343                             Pyrgulopsis sathos                       R8
# 344                          Pyrgulopsis saxatilis                       R6
# 345                            Pyrgulopsis serrata                       R8
# 346                           Pyrgulopsis sterilis                       R8
# 347                            Pyrgulopsis sublata                       R8
# 348                            Pyrgulopsis sulcata                       R8
# 349                          Pyrgulopsis turbatrix                       R8
# 350                              Sonorella eremita                       R2
# 351                          Sonorella grahamensis                       R2
# 352                         Sonorella macrophallus                       R2
# 353                             Trilobopsis roperi                       R8
# 354                               Tryonia angulata                       R8
# 355                              Tryonia clathrata                       R8
# 356                                  Tryonia elata                       R8
# 357                                 Tryonia ericae                       R8
# 358                          Tryonia quitobaquitae                       R2
# 359                              Tryonia variegata                       R8
# 360                                    Vertigo sp.                       R1
# 361                          Vespericola pressleyi                       R8
# 362                             Vespericola shasta                       R8
#
#                                          Species Range  \
# 0                                   AL, KY, OH, TN, WV
# 1                               CO, ID, NM, NV, UT, WY
# 2                                                   CA
# 3                                                   CA
# 4                                                   CA
# 5                                                   CA
# 6                                                   CA
# 7                                               OR, WA
# 8                                   AZ, CA, NM, NV, UT
# 9    AL, AR, GA, IL, IN, KY, MD, MO, MS, NC, NY, OH...
# 10                                                  TX
# 11                                                  TX
# 12                                                  TX
# 13                                                  TX
# 14                                                  TX
# 15                                          OK, MO, AR
# 16                                                  TN
# 17                                          AL, GA, TN
# 18                                                  WV
# 19                                              FL, GA
# 20                                                  CA
# 21                                                  CA
# 22                                                  NC
# 23                                              FL, GA
# 24                                                  VA
# 25                                          AR, IL, MO
# 26                                              CA, OR
# 27                                              OR, WA
# 28                                              OR, WA
# 29                                              OR, WA
# ..                                                 ...
# 333                                                 NV
# 334                                                 NV
# 335                                                 NV
# 336                                                 NV
# 337                                                 NV
# 338                                                 NV
# 339                                             MO, AR
# 340                                             NV, UT
# 341                                                 NV
# 342                                                 NV
# 343                                                 NV
# 344                                                 UT
# 345                                                 NV
# 346                                                 NV
# 347                                                 NV
# 348                                                 NV
# 349                                                 NV
# 350                                                 AZ
# 351                                                 AZ
# 352                                                 AZ
# 353                                                 CA
# 354                                                 NV
# 355                                                 NV
# 356                                                 NV
# 357                                                 NV
# 358                                                 AZ
# 359                                             CA, NV
# 360                                                 WA
# 361                                                 CA
# 362                                                 CA
#
#                                     ScientificNameLink
# 0                https://ecos.fws.gov/ecp/species/9776
# 1                https://ecos.fws.gov/ecp/species/1114
# 2                https://ecos.fws.gov/ecp/species/2095
# 3                https://ecos.fws.gov/ecp/species/9277
# 4                https://ecos.fws.gov/ecp/species/7408
# 5                https://ecos.fws.gov/ecp/species/9274
# 6                https://ecos.fws.gov/ecp/species/5736
# 7                 https://ecos.fws.gov/ecp/species/913
# 8                https://ecos.fws.gov/ecp/species/2077
# 9    https://ecos.fws.gov/ecp0/profile/speciesProfi...
# 10               https://ecos.fws.gov/ecp/species/4624
# 11   https://ecos.fws.gov/ecp0/profile/speciesProfi...
# 12                 https://ecos.fws.gov/ecp/species/29
# 13   https://ecos.fws.gov/ecp0/profile/speciesProfi...
# 14               https://ecos.fws.gov/ecp/species/2890
# 15               https://ecos.fws.gov/ecp/species/4096
# 16               https://ecos.fws.gov/ecp/species/4043
# 17               https://ecos.fws.gov/ecp/species/5131
# 18               https://ecos.fws.gov/ecp/species/1835
# 19               https://ecos.fws.gov/ecp/species/8465
# 20               https://ecos.fws.gov/ecp/species/2773
# 21               https://ecos.fws.gov/ecp/species/6607
# 22               https://ecos.fws.gov/ecp/species/6772
# 23               https://ecos.fws.gov/ecp/species/5856
# 24               https://ecos.fws.gov/ecp/species/3529
# 25                https://ecos.fws.gov/ecp/species/455
# 26               https://ecos.fws.gov/ecp/species/5133
# 27               https://ecos.fws.gov/ecp/species/7827
# 28               https://ecos.fws.gov/ecp/species/1375
# 29               https://ecos.fws.gov/ecp/species/3376
# ..                                                 ...
# 333              https://ecos.fws.gov/ecp/species/8987
# 334              https://ecos.fws.gov/ecp/species/8989
# 335              https://ecos.fws.gov/ecp/species/4778
# 336              https://ecos.fws.gov/ecp/species/5868
# 337              https://ecos.fws.gov/ecp/species/8991
# 338              https://ecos.fws.gov/ecp/species/8992
# 339  https://ecos.fws.gov/ecp0/profile/speciesProfi...
# 340              https://ecos.fws.gov/ecp/species/8994
# 341              https://ecos.fws.gov/ecp/species/2997
# 342              https://ecos.fws.gov/ecp/species/8995
# 343              https://ecos.fws.gov/ecp/species/8996
# 344              https://ecos.fws.gov/ecp/species/8997
# 345              https://ecos.fws.gov/ecp/species/8998
# 346              https://ecos.fws.gov/ecp/species/8999
# 347              https://ecos.fws.gov/ecp/species/9000
# 348              https://ecos.fws.gov/ecp/species/9001
# 349              https://ecos.fws.gov/ecp/species/9002
# 350              https://ecos.fws.gov/ecp/species/1015
# 351              https://ecos.fws.gov/ecp/species/7840
# 352              https://ecos.fws.gov/ecp/species/4377
# 353              https://ecos.fws.gov/ecp/species/8849
# 354              https://ecos.fws.gov/ecp/species/6645
# 355               https://ecos.fws.gov/ecp/species/303
# 356              https://ecos.fws.gov/ecp/species/7837
# 357              https://ecos.fws.gov/ecp/species/2556
# 358              https://ecos.fws.gov/ecp/species/4521
# 359              https://ecos.fws.gov/ecp/species/6906
# 360              https://ecos.fws.gov/ecp/species/8761
# 361              https://ecos.fws.gov/ecp/species/8850
# 362              https://ecos.fws.gov/ecp/species/8896
#
# [363 rows x 6 columns]

# %% [markdown]
# Get the collection we want to put these data into from the Data Distillery MongoDB instance.

# %%
bisDB = dd.getDB("bis")
esaWPSpecies = bisDB["FWS ESA Work Plan Species"]

# %% [markdown]
# Insert the original submitted data into the MongoDB collection as a data structure.

# %%
fwsESASpeciesList = []

for index,row in df.iterrows():
    speciesRecord = {}
    speciesRecord["Submitted Data"] = packageESASpeciesRow(row)
    speciesRecord["Processing Metadata"] = {"Date Created from Source":datetime.utcnow().isoformat()}
    fwsESASpeciesList.append(speciesRecord)

esaWPSpecies.delete_many({})
esaWPSpecies.insert_many(fwsESASpeciesList)

# %% [markdown]
# Parse out the range places (state abbreviations and other place names) into their own data structure for later processing and comparison.

# %%
for record in esaWPSpecies.find():
    fwsRange = {"US States":[],"US State List":[],"Other Places":[]}
    for rangePlace in record["Submitted Data"]["Species Range"].replace(", ",",").split(","):
        rangeState = lookupState(rangePlace)
        if rangeState is None:
            fwsRange["Other Places"].append({rangePlace:{}})
        else:
            fwsRange["US States"].append({rangePlace:rangeState})
            fwsRange["US State List"].append(rangePlace)

    if len(fwsRange["Other Places"]) == 0:
        del fwsRange["Other Places"]

    esaWPSpecies.update_one({"_id":record["_id"]},{"$set":{"FWS Range":fwsRange}})

# %% [markdown]
# Show what the final data structure looks like at this point.

# %%
display(esaWPSpecies.find_one())
# Out:
# {'FWS Range': {'US State List': ['AL', 'KY', 'OH', 'TN', 'WV'],
#   'US States': [{'AL': {'fips': '01', 'name': 'Alabama'}},
#    {'KY': {'fips': '21', 'name': 'Kentucky'}},
#    {'OH': {'fips': '39', 'name': 'Ohio'}},
#    {'TN': {'fips': '47', 'name': 'Tennessee'}},
#    {'WV': {'fips': '54', 'name': 'West Virginia'}}]},
#  'Processing Metadata': {'Date Created from Source': '2018-02-21T13:38:13.076667'},
#  'Submitted Data': {'Common Name': 'streamside salamander',
#   'Grouping': 'Amphibians',
#   'Lead FWS Region': 'R4',
#   'Scientific Name': 'Ambystoma barbouri',
#   'Species Range': 'AL, KY, OH, TN, WV',
#   'Species Record Reference': 'https://ecos.fws.gov/ecp/species/9776'},
#  '_id': ObjectId('5a8d76450601ba07d55ba317')}
