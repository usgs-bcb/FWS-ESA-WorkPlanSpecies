# %% [markdown]
# Perhaps one of the most important aspects of building a continuous stream of new information associated with species in the FWS work plan or other circumstances is the ability to identify and access new published literature. Many of the structured databases assembled and organized into this collection are based wholly or partly in literature references and information extracted from literature. We are currently working with the team developing the xDD Digital Library on a number of tools and techniques for a) identifying literature potentially applicable to species-based research and b) using natural language processing tools to pull specific data from those sources for use. This is an ongoing effort that will result in improved production capabilities over time.
#
# In the near term, we take advantage of some basic and enhanced search functionality to identify potential articles of interested in the xDD library of millions of documents that are increasing daily. The xdd module in the bispy package contains some search and packaging functionality that interfaces with the xDD REST API.

# %%
import requests
import json
import bispy
from IPython.display import display
from joblib import Parallel, delayed
import random

xdd = bispy.xdd.Xdd()

# %%
# Open up the cached workplan species
with open("cache/workplan_species.json", "r") as f:
    workplan_species = json.loads(f.read())

# %%
# Use joblib to run multiple requests for SGCN records in parallel via scientific names
xdd_results = Parallel(n_jobs=8)(delayed(xdd.snippets)(name) for name in [r["Scientific Name"] for r in workplan_species])

# %%
# Dump the records we discovered and packaged to a cache file
# I need to revisit this once I get some things cleared up with taxonomic matching to hopefully find more records
with open("cache/xdd.json", "w") as f:
    f.write(json.dumps([x for x in xdd_results if "Number Documents" in x["Processing Metadata"].keys() and x["Processing Metadata"]["Number Documents"] > 0], indent=4))

# %%
# Open the file back up and verify
with open("cache/xdd.json", "r") as f:
    xdd_cache = json.loads(f.read())

print(len(xdd_cache))
display(xdd_cache[random.randint(0,len(xdd_cache)-1)])
# Out:
# 271
# {'Data': [{'URL': 'http://www.sciencedirect.com/science/article/pii/S1470160X01000036',
#    '_gddid': '579f8f51cf58f138945af82b',
#    'authors': 'Dale, Virginia H.; Beyeler, Suzanne C.',
#    'coverDate': 'August 2001',
#    'doi': '10.1016/S1470-160X(01)00003-6',
#    'highlight': ['many other species (e.g. the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) that occupy',
#     'Strix occidentalis caurina) that occupy old growth forest in the Paciﬁc'],
#    'publisher': 'Elsevier',
#    'pubname': 'Ecological Indicators',
#    'title': 'Challenges in the development and use of ecological indicators'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/abs/10.1139/x98-039',
#    '_gddid': '57985e4dcf58f139fabbd5a0',
#    'authors': 'Acker, S A; Zenner, E K; Emmingham, W H',
#    'coverDate': 'May 1998',
#    'doi': '10.1139/x98-039',
#    'highlight': ['forests within the range of the northern spotted owl (Strix occidentalis caurina;',
#     'the northern spotted owl (Strix occidentalis caurina; USDA Forest',
#     'Strix occidentalis caurina; USDA Forest Service and USDI Bureau of'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Forest Research',
#    'title': 'Structure and yield of two-aged stands on the Willamette National Forest, Oregon: implications for green tree retention'},
#   {'URL': 'http://doi.wiley.com/10.1890/02-0719',
#    '_gddid': '58333e43cf58f177a7b78811',
#    'authors': 'Zabel, Richard W.; Achord, Stephen',
#    'coverDate': '2004 03',
#    'doi': '10.1890/02-0719',
#    'highlight': ['1988. Demographic models of the Northern spotted Owl (Strix occidentalis caurina).',
#     'the Northern spotted Owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75:601–607. Lawler, J. L., S.'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'RELATING SIZE OF JUVENILES TO SURVIVAL WITHIN AND AMONG POPULATIONS OF CHINOOK SALMON'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079290840J',
#    '_gddid': '57f842c1cf58f19caa6fa160',
#    'authors': '',
#    'coverDate': '1992',
#    'doi': '10.1016/0006-3207(92)90840-J',
#    'highlight': ['Models of  these processes are applied to data on Strix occidentalis  caurina',
#     'are applied to data on Strix occidentalis  caurina inhabiting',
#     'Strix occidentalis  caurina inhabiting old-growth forests in the US'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'The golden-backed uacari on the upper Rio Negro, Brazil A. Barnett & A. Celeste da Cunha, Oryx, 25(2), 1991, pp 80–88'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079290843C',
#    '_gddid': '57f85452cf58f1a2db16d883',
#    'authors': '',
#    'coverDate': '1992',
#    'doi': '10.1016/0006-3207(92)90843-C',
#    'highlight': ['Models of  these processes are applied to data on Strix occidentalis  caurina',
#     'are applied to data on Strix occidentalis  caurina inhabiting',
#     'Strix occidentalis  caurina inhabiting old-growth forests in the US'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Conservation of the Yellowstone grizzly bear D.J. Mattson & M.M. Reid, Conservation Biology, 5(3), 1991, pp 364–372'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0378112713006579',
#    '_gddid': '577bdefbcf58f15bef495d3c',
#    'authors': 'Wimberly, Michael C.; Liu, Zhihua',
#    'coverDate': '1 September 2014',
#    'doi': '10.1016/j.foreco.2013.09.043',
#    'highlight': ['associated species such as the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) (Everett',
#     'Strix occidentalis caurina) (Everett et al., 1997). A relatively high',
#     '2007. Modeling wildﬁre risk to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat in Central Oregon, USA. For. Ecol.'],
#    'publisher': 'Elsevier',
#    'pubname': 'Forest Ecology and Management',
#    'title': 'Interactions of climate, fire, and management in future forests of the Pacific Northwest'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/0169534793901145',
#    '_gddid': '569fbe56cf58f187a4256951',
#    'authors': 'Swaine, M.D.',
#    'coverDate': 'June 1993',
#    'doi': '10.1016/0169-5347(93)90114-5',
#    'highlight': ['on  spatial models of the northern spot-  ted owl (Strix occidentalis caurina)  is',
#     'northern spot-  ted owl (Strix occidentalis caurina)  is too',
#     'Strix occidentalis caurina)  is too recent to be referenced.] The  authors'],
#    'publisher': 'Elsevier',
#    'pubname': 'Trends in Ecology & Evolution',
#    'title': 'The conservation atlas of tropical forests: Africa edited by J.A. Sayer, C.S. Harcourt, and N.M. Collins, Macmillan, 1992. £75.00 hbk (vii t 288 pages) ISBN 0 333 57757 4'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0098300400001734',
#    '_gddid': '563e5201cf58f18954974b3c',
#    'authors': 'Coops, Nicholas C; Catling, Peter C',
#    'coverDate': 'August 2001',
#    'doi': '10.1016/S0098-3004(00)00173-4',
#    'highlight': ['Owl, in the Paciﬁc Northwest of the United States (Strix occidentalis caurina)',
#     'Northwest of the United States (Strix occidentalis caurina) not only',
#     'Strix occidentalis caurina) not only the total reserved area, but also'],
#    'publisher': 'Elsevier',
#    'pubname': 'Computers & Geosciences',
#    'title': 'Prediction of historical forest habitat patterns using binomial distributions and simple Boolean logic from high spatial resolution remote sensing'},
#   {'URL': 'http://www.bioone.org/doi/abs/10.2193/2007-341',
#    '_gddid': '572c8298cf58f10e81deaab0',
#    'authors': 'Jacobs, Katherine M.; Luoma, Daniel L.',
#    'coverDate': 'November 2008',
#    'doi': '10.2193/2007-341',
#    'highlight': ['forest predators such as the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Pretreatment',
#     'Strix occidentalis caurina). Pretreatment diets showed differences',
#     'predators, including the threatened northern spotted owl (Strix occidentalis caurina;',
#     'threatened northern spotted owl (Strix occidentalis caurina; Forsman',
#     'Strix occidentalis caurina; Forsman et al. 1984). The mammal–fungus–tree'],
#    'publisher': 'Wiley',
#    'pubname': 'Journal of Wildlife Management',
#    'title': 'Small Mammal Mycophagy Response to Variations in Green-Tree Retention'},
#   {'URL': 'http://www.bioone.org/doi/abs/10.2193/2005-608',
#    '_gddid': '572c9307cf58f113938940e9',
#    'authors': 'RAITHEL, JAROD D.; KAUFFMAN, MATTHEW J.; PLETSCHER, DANIEL H.',
#    'coverDate': 'May 2007',
#    'doi': '10.2193/2005-608',
#    'highlight': ['caretta; Crouse et al. 1987) and northern spotted owl (Strix occidentalis caurina;',
#     'and northern spotted owl (Strix occidentalis caurina; Noon and',
#     'Strix occidentalis caurina; Noon and Biles 1990) populations. Adult'],
#    'publisher': 'Wiley',
#    'pubname': 'Journal of Wildlife Management',
#    'title': 'Impact of Spatial and Temporal Variation in Calf Survival on the Growth of Elk Populations'},
#   {'URL': 'http://doi.wiley.com/10.1002/jwmg.218',
#    '_gddid': '5c86783b1faed65548992bf1',
#    'authors': 'Irwin, Larry L.; Rock, Dennis F.; Rock, Suzanne C.',
#    'coverDate': '2012 01',
#    'doi': '10.1002/jwmg.218',
#    'highlight': ['for the federally threatened northern spotted owl (Strix occidentalis caurina)',
#     'threatened northern spotted owl (Strix occidentalis caurina) requires',
#     'Strix occidentalis caurina) requires an ability to predict their responses',
#     'resource selection function, risk assessment, RSF, Strix occidentalis caurina.  Public',
#     'function, risk assessment, RSF, Strix occidentalis caurina.  Public',
#     'Strix occidentalis caurina.  Public forest and resource managers in',
#     '2007. Modeling ﬁre risk to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat in central Oregon, USA. Forest',
#     'Final recovery plan for the northern spotted owl, Strix occidentalis caurina.',
#     'the northern spotted owl, Strix occidentalis caurina. United',
#     'Strix occidentalis caurina. United States Fish and Wildlife Service,',
#     'revised recovery plan for the northern spotted owl, Strix occidentalis caurina.',
#     'the northern spotted owl, Strix occidentalis caurina. United',
#     'Strix occidentalis caurina. United States Fish and Wildlife Service,',
#     'and habitat-use patterns of northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Canadian',
#     'Strix occidentalis caurina). Canadian Journal of Zoology 73:433–439. Associate'],
#    'publisher': 'Wiley',
#    'pubname': 'The Journal of Wildlife Management',
#    'title': 'Habitat selection by northern spotted owls in mixed-coniferous forests'},
#   {'URL': 'http://doi.wiley.com/10.1002/jwmg.513',
#    '_gddid': '5c867f481faed65548992c43',
#    'authors': 'Schultz, Courtney A.; Sisk, Thomas D.; Noon, Barry R.; Nie, Martin A.',
#    'coverDate': '2013 04',
#    'doi': '10.1002/jwmg.513',
#    'highlight': ['initiated litigation over the northern spotted owl (Strix occidentalis caurina),',
#     'the northern spotted owl (Strix occidentalis caurina), and led',
#     'Strix occidentalis caurina), and led the courts to reject forest plans'],
#    'publisher': 'Wiley',
#    'pubname': 'The Journal of Wildlife Management',
#    'title': "Wildlife conservation planning under the United States Forest Service's 2012 planning rule"},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/016953478690073X',
#    '_gddid': '56a01880cf58f187a4256c20',
#    'authors': 'Wilcox, Bruce A.',
#    'coverDate': 'August 1986',
#    'doi': '10.1016/0169-5347(86)90073-X',
#    'highlight': ['spotted owl  ogy heretofore confined to pure or (Strix occidentalis caurina),',
#     'heretofore confined to pure or (Strix occidentalis caurina), a sub-  basic',
#     'Strix occidentalis caurina), a sub-  basic research (exceptions being'],
#    'publisher': 'Elsevier',
#    'pubname': 'Trends in Ecology & Evolution',
#    'title': 'Extinction models and conservation'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0169534715001378',
#    '_gddid': '569e6d96cf58f187a4255f2e',
#    'authors': 'Lowe, Winsor H.; Muhlfeld, Clint C.; Allendorf, Fred W.',
#    'coverDate': 'August 2015',
#    'doi': '10.1016/j.tree.2015.05.008',
#    'highlight': ['into the native range of the northern spotted owl (Strix occidentalis caurina),',
#     'the northern spotted owl (Strix occidentalis caurina), leading',
#     'Strix occidentalis caurina), leading to hybridization between the two'],
#    'publisher': 'Elsevier',
#    'pubname': 'Trends in Ecology & Evolution',
#    'title': 'Spatial sorting promotes the spread of maladaptive hybridization'},
#   {'URL': 'http://doi.wiley.com/10.2307/2937171',
#    '_gddid': '58333b76cf58f177a7b782bd',
#    'authors': 'Lebreton, Jean-Dominique; Burnham, Kenneth P.; Clobert, Jean; Anderson, David R.',
#    'coverDate': '1992 02',
#    'doi': '10.2307/2937171',
#    'highlight': ['Meslow. 1990. 1990 status review: northern spotted owl (Strix occidentalis caurina).',
#     'review: northern spotted owl (Strix occidentalis caurina). United',
#     'Strix occidentalis caurina). United States Unpublished report. United'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Monographs',
#    'title': 'Modeling Survival and Testing Biological Hypotheses Using Marked Animals: A Unified Approach with Case Studies'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1523-1739.2010.01489.x',
#    '_gddid': '583cf89bcf58f18aa28bb808',
#    'authors': 'AKTER, SONIA; GRAFTON, R. QUENTIN',
#    'coverDate': '2010 10',
#    'doi': '10.1111/j.1523-1739.2010.01489.x',
#    'highlight': ['benefits of conservation of the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). The estimated',
#     'Strix occidentalis caurina). The estimated benefit (nonuse value) of'],
#    'publisher': 'Wiley',
#    'pubname': 'Conservation Biology',
#    'title': 'Confronting Uncertainty and Missing Values in Environmental Value Transfer as Applied to Species Conservation'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1744-7429.2009.00615.x',
#    '_gddid': '583aa676cf58f18581e8c5a0',
#    'authors': 'Rigg, Lesley S.; Enright, Neal J.; Jaffré, Tanguy; Perry, George L. W.',
#    'coverDate': '2010 07',
#    'doi': '10.1111/j.1744-7429.2009.00615.x',
#    'highlight': ['1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75: 601–607. LATHAM, M., P.'],
#    'publisher': 'Wiley',
#    'pubname': 'Biotropica',
#    'title': 'Contrasting Population Dynamics of the Endemic New Caledonian Conifer Araucaria laubenfelsii in Maquis and Rain Forest'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0006320710003836',
#    '_gddid': '57a77728cf58f138c32c9ed9',
#    'authors': 'Galpern, Paul; Manseau, Micheline; Fall, Andrew',
#    'coverDate': 'January 2011',
#    'doi': '10.1016/j.biocon.2010.09.002',
#    'highlight': ['valley, California, USA  22 Sutherland et al. (2007)  Strix occidentalis caurina',
#     'Sutherland et al. (2007)  Strix occidentalis caurina Northern',
#     'Strix occidentalis caurina Northern spotted owl  Southern British Columbia,'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Patch-based graphs of landscape connectivity: A guide to construction, analysis and application for conservation'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/abs/10.1139/z99-204',
#    '_gddid': '57a3d708cf58f1b6feb1b0fe',
#    'authors': 'Savignac, Carl; Desrochers, André; Huot, Jean',
#    'coverDate': 'March 2000',
#    'doi': '10.1139/z99-204',
#    'highlight': ['multiscale studies. Examples are the Northern Spotted Owl (Strix occidentalis caurina',
#     'the Northern Spotted Owl (Strix occidentalis caurina Merriam)',
#     'Strix occidentalis caurina Merriam) in the Pacific Northwest region'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Zoology',
#    'title': 'Habitat use by Pileated Woodpeckers at two spatial scales in eastern Canada'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0921800912004156',
#    '_gddid': '5715f304cf58f1b1f9bd0e32',
#    'authors': 'Weber, Michelle',
#    'coverDate': 'January 2013',
#    'doi': '10.1016/j.ecolecon.2012.09.020',
#    'highlight': ['Species Act listing of the Northern Spotted Owl (Strix occidentalis caurina)',
#     'the Northern Spotted Owl (Strix occidentalis caurina) Nelson',
#     'Strix occidentalis caurina) Nelson concludes that individual species'],
#    'publisher': 'Elsevier',
#    'pubname': 'Ecological Economics',
#    'title': 'DanielPaulyCritical Review of 5 Easy Pieces: The Impact of Fisheries on Marine Ecosystems2010Island Press193 pp. ISBN-13:978-1-59726-718-2'},
#   {'URL': 'http://www.tandfonline.com/doi/abs/10.1300/J091v21n02_13',
#    '_gddid': '595a5a80cf58f17497a44f39',
#    'authors': 'Niklasson, Mats; Nilsson, Sven G.; Hedin, Jonas; Caldiz, Mayra S.; Bobiec, Andrzej',
#    'coverDate': '2006 01',
#    'doi': '10.1300/J091v21n02_13',
#    'highlight': ['the northwestern U.S.A., the northern spotted owl (Strix occidentalis caurina',
#     'the northern spotted owl (Strix occidentalis caurina de Vesey)',
#     'Strix occidentalis caurina de Vesey) became a species under heavy debate'],
#    'publisher': 'Taylor and Francis',
#    'pubname': 'Journal of Sustainable Forestry',
#    'title': 'Sustainability and Biodiversity'},
#   {'URL': 'http://www.tandfonline.com/doi/full/10.1080/00324728.2015.1122826',
#    '_gddid': '5952f8e4cf58f195d9b321cf',
#    'authors': 'Bijak, Jakub; Bryant, John',
#    'coverDate': '2016 03',
#    'doi': '10.1080/00324728.2015.1122826',
#    'highlight': ['mysticetus, Raftery et al. 1995) and northern spotted owls (Strix occidentalis caurina,',
#     'northern spotted owls (Strix occidentalis caurina, Clark',
#     'Strix occidentalis caurina, Clark 2003). Since the 1990s, both the'],
#    'publisher': 'Taylor and Francis',
#    'pubname': 'Population Studies',
#    'title': 'Bayesian demography 250\u2005years after Bayes'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S030438000300005X',
#    '_gddid': '57ff266bcf58f1b292ed3443',
#    'authors': 'Goldstein, Michael I.; Corson, Michael S.; Lacher, Thomas E.; Grant, William E.',
#    'coverDate': '1 April 2003',
#    'doi': '10.1016/S0304-3800(03)00005-X',
#    'highlight': ['(1992), in a study intended for Northern Spotted Owls (Strix occidentalis caurina)',
#     'Northern Spotted Owls (Strix occidentalis caurina) in northwestern',
#     'Strix occidentalis caurina) in northwestern forests, described ﬁve'],
#    'publisher': 'Elsevier',
#    'pubname': 'Ecological Modelling',
#    'title': 'Managed forests and migratory bird populations: evaluating spatial configurations through simulation'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1442-9993.2011.02247.x',
#    '_gddid': '583adeb6cf58f197540c166f',
#    'authors': 'DAWSON, M. J.; HONE, J.',
#    'coverDate': '2012 02',
#    'doi': '10.1111/j.1442-9993.2011.02247.x',
#    'highlight': ['(1988) Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75, 601–7. Lebreton J.-D., Burnham'],
#    'publisher': 'Wiley',
#    'pubname': 'Austral Ecology',
#    'title': 'Demography and dynamics of three wild horse populations in the Australian Alps'},
#   {'URL': 'http://doi.wiley.com/10.1890/13-1653.1',
#    '_gddid': '583901c9cf58f1072de036f7',
#    'authors': 'Halofsky, Joshua S.; Halofsky, Jessica E.; Burcsu, Theresa; Hemstrom, Miles A.',
#    'coverDate': '2014 12',
#    'doi': '10.1890/13-1653.1',
#    'highlight': ['wildlife species, including the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). Increased',
#     'Strix occidentalis caurina). Increased ﬁre hazard in these moist mixed-conifer',
#     '2007. Modeling wildﬁre risk to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat in Central Oregon, USA. Forest'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'Dry forest resilience varies under simulated climate-management scenarios in a central Oregon, USA landscape'},
#   {'URL': 'http://doi.wiley.com/10.1890/10-2142.1',
#    '_gddid': '58392d1fcf58f11407fa8e07',
#    'authors': 'Dugger, Katie M.; Anthony, Robert G.; Andrews, Lawrence S.',
#    'coverDate': '2011 10',
#    'doi': '10.1890/10-2142.1',
#    'highlight': ['co-occurs with the endemic Northern Spotted Owl (Strix occidentalis caurina),',
#     'endemic Northern Spotted Owl (Strix occidentalis caurina), resulted',
#     'Strix occidentalis caurina), resulted in a unique opportunity to investigate',
#     'modeling; old forest; Southern Cascades, Oregon, USA; Strix occidentalis caurina;',
#     'Cascades, Oregon, USA; Strix occidentalis caurina; Strix',
#     'Strix occidentalis caurina; Strix varia.  INTRODUCTION The Northern',
#     'Strix varia.  INTRODUCTION The Northern Spotted Owl (Strix occidentalis caurina)',
#     'varia.  INTRODUCTION The Northern Spotted Owl (Strix occidentalis caurina) was listed',
#     'Strix occidentalis caurina) was listed federally as threatened by the',
#     '2).  FIG. 1. Annual proportion of Northern Spotted Owl (Strix occidentalis caurina)',
#     'of Northern Spotted Owl (Strix occidentalis caurina) territories',
#     'Strix occidentalis caurina) territories with Barred Owl (Strix varia)',
#     'colonization (c) probabilities of Northern Spotted Owl (Strix occidentalis caurina)',
#     'of Northern Spotted Owl (Strix occidentalis caurina) pairs',
#     'Strix occidentalis caurina) pairs on territories in southern Oregon,',
#     'Final recovery plan for the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). U.S.',
#     'Strix occidentalis caurina). U.S. Department of the Interior, Fish'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'Transient dynamics of invasive competition: Barred Owls, Spotted Owls, habitat, and the demons of competition present'},
#   {'URL': 'http://doi.wiley.com/10.1111/cobi.12726',
#    '_gddid': '583ccaf0cf58f17b08d79b06',
#    'authors': 'Aiello-Lammens, Matthew E.; Akçakaya, H. Resit',
#    'coverDate': '2016 11',
#    'doi': '10.1111/cobi.12726',
#    'highlight': ['small impact (10% decline in Northern Spotted Owl [Strix occidentalis caurina]',
#     'in Northern Spotted Owl [Strix occidentalis caurina] habitat',
#     'Strix occidentalis caurina] habitat over 100 years) results in substantial'],
#    'publisher': 'Wiley',
#    'pubname': 'Conservation Biology',
#    'title': 'Using global sensitivity analysis of demographic models for ecological impact assessment'},
#   {'URL': 'http://doi.wiley.com/10.1002/ecy.1805',
#    '_gddid': '58e2bf1ccf58f1666e007006',
#    'authors': 'Rockweit, Jeremy T.; Franklin, Alan B.; Carlson, Peter C.',
#    'coverDate': '2017 03',
#    'doi': '10.1002/ecy.1805',
#    'highlight': ['created by wildfire was the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Although',
#     'Strix occidentalis caurina). Although generally considered an old-growth',
#     'Revised Recovery Plan for the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). Pages',
#     'Strix occidentalis caurina). Pages 1–258 U.S. Fish and Wildlife Service.'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'Differential Impacts of Wildfire on the Population Dynamics of an Old-Forest Species'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0006320714004765',
#    '_gddid': '57a83adfcf58f16d6528fa69',
#    'authors': 'Stabach, J.A.; Boone, R.B.; Worden, J.S.; Florant, G.',
#    'coverDate': 'February 2015',
#    'doi': '10.1016/j.biocon.2014.12.003',
#    'highlight': ['Munshi-South et al., 2008; northern spotted owl (Strix occidentalis caurina),',
#     '2008; northern spotted owl (Strix occidentalis caurina), Wasser',
#     'Strix occidentalis caurina), Wasser et al., 1997). Understanding the'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Habitat disturbance effects on the physiological stress response in resident Kenyan white-bearded wildebeest (Connochaetes taurinus)'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0006320706001923',
#    '_gddid': '57a9ad2ecf58f12ab106ae05',
#    'authors': 'Haines, Aaron M.; Tewes, Michael E.; Laack, Linda L.; Horne, Jon S.; Young, John H.',
#    'coverDate': 'October 2006',
#    'doi': '10.1016/j.biocon.2006.04.035',
#    'highlight': ['Polioptila californica californica, and spotted owl Strix occidentalis caurina',
#     'californica, and spotted owl Strix occidentalis caurina (Akc¸ akaya',
#     'Strix occidentalis caurina (Akc¸ akaya et al., 1995; Akcakaya and Atwood,'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'A habitat-based population viability analysis for ocelots (Leopardus pardalis) in the United States'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/B9780080453378002679',
#    '_gddid': '587915cdcf58f120fbe66507',
#    'authors': 'Hayward, L.S.; Busch, D.S.',
#    'coverDate': '2010',
#    'doi': '10.1016/B978-0-08-045337-8.00267-9',
#    'highlight': ['sleeping in species like the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Behavioral',
#     'Strix occidentalis caurina). Behavioral data can provide the social'],
#    'publisher': 'Elsevier',
#    'pubname': 'Encyclopedia of Animal Behavior',
#    'title': 'Conservation Behavior and Endocrinology'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1523-1739.2005.00212.x',
#    '_gddid': '583cf772cf58f18a3b16947a',
#    'authors': 'CZECH, BRIAN',
#    'coverDate': '2005 08',
#    'doi': '10.1111/j.1523-1739.2005.00212.x',
#    'highlight': ['Lycaeides melissa samuelis Northern Spotted Owl, Strix occidentalis caurina',
#     'samuelis Northern Spotted Owl, Strix occidentalis caurina Razorback',
#     'Strix occidentalis caurina Razorback sucker, Xyrauchen texanus Steller'],
#    'publisher': 'Wiley',
#    'pubname': 'Conservation Biology',
#    'title': 'The Capacity of the National Wildlife Refuge System to Conserve Threatened and Endangered Animal Species in the United States'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0034425714000443',
#    '_gddid': '5804de21cf58f1667e08c62b',
#    'authors': 'Garabedian, James E.; McGaughey, Robert J.; Reutebuch, Stephen E.; Parresol, Bernard R.; Kilgo, John C.; Moorman, Christopher E.; Peterson, M. Nils',
#    'coverDate': '5 April 2014',
#    'doi': '10.1016/j.rse.2014.01.022',
#    'highlight': ['throughout the range of the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) by linking',
#     'Strix occidentalis caurina) by linking ﬁne-grained habitat data collected',
#     'Revised recovery plan for the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Portland,',
#     'Strix occidentalis caurina). Portland, Oregon, USA: U.S. Fish and Wildlife'],
#    'publisher': 'Elsevier',
#    'pubname': 'Remote Sensing of Environment',
#    'title': 'Quantitative analysis of woodpecker habitat using high-resolution airborne LiDAR estimates of forest structure and composition'},
#   {'URL': 'http://doi.wiley.com/10.2307/2269391',
#    '_gddid': '5838f030cf58f101eb8b3e37',
#    'authors': 'Heppell, Selina S.; Crowder, Larry B.; Crouse, Deborah T.',
#    'coverDate': '1996 05',
#    'doi': '10.2307/2269391',
#    'highlight': ['1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75:601-607. Noon, B. R., and'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'Models to Evaluate Headstarting as a Management Tool for Long-Lived Turtles'},
#   {'URL': 'http://doi.wiley.com/10.1890/03-6002',
#    '_gddid': '5839dce4cf58f1410e2325e9',
#    'authors': 'Nelson, Cara R.; Halpern, Charles B.',
#    'coverDate': '2005 02',
#    'doi': '10.1890/03-6002',
#    'highlight': ['lands within the range of the northern spotted owl (Strix occidentalis caurina),',
#     'the northern spotted owl (Strix occidentalis caurina), forest',
#     'Strix occidentalis caurina), forest managers are now required to retain'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'EDGE-RELATED RESPONSES OF UNDERSTORY PLANTS TO AGGREGATED RETENTION HARVEST IN THE PACIFIC NORTHWEST'},
#   {'URL': 'http://doi.wiley.com/10.1890/03-0513',
#    '_gddid': '5835583fcf58f17c8e6fef2d',
#    'authors': 'Oli, Madan K.; Armitage, Kenneth B.',
#    'coverDate': '2004 09',
#    'doi': '10.1890/03-0513',
#    'highlight': ['1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75:601–607. Lenihan, C., and'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'YELLOW-BELLIED MARMOT POPULATION DYNAMICS: DEMOGRAPHIC MECHANISMS OF GROWTH AND DECLINE'},
#   {'URL': 'http://www.tandfonline.com/doi/abs/10.1080/08941920.2014.933920',
#    '_gddid': '59540ad6cf58f132d2d405d1',
#    'authors': 'Erickson, Adam M.',
#    'coverDate': '2014 08',
#    'doi': '10.1080/08941920.2014.933920',
#    'highlight': ['forest habitat selection by northern spotted owl (Strix occidentalis caurina),',
#     'by northern spotted owl (Strix occidentalis caurina), enabling',
#     'Strix occidentalis caurina), enabling use of the subspecies as an indicator'],
#    'publisher': 'Taylor and Francis',
#    'pubname': 'Society & Natural Resources',
#    'title': 'Nested Localized Institutions for Adaptive Co-Management: A History of State Watershed Management in the Pacific Region of the United States'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1474-919X.1998.tb04722.x',
#    '_gddid': '58b1166acf58f1484521fafb',
#    'authors': '',
#    'coverDate': '1998 10',
#    'doi': '10.1111/j.1474-919X.1998.tb04722.x',
#    'highlight': ['subspecies, three of them birds (Northern Spotted Owl Strix occidentalis caurina,',
#     'birds (Northern Spotted Owl Strix occidentalis caurina, Red-cockaded',
#     'Strix occidentalis caurina, Red-cockaded WoodpeckerPicoides borealis'],
#    'publisher': 'Wiley',
#    'pubname': 'Ibis',
#    'title': 'RECENT ORNITHOLOGICAL PUBLICATIONS'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/10.1139/x98-039',
#    '_gddid': '5c40c3161faed655488d0b5a',
#    'authors': 'Acker, S A; Zenner, E K; Emmingham, W H',
#    'coverDate': 'May 1998',
#    'doi': '10.1139/x98-039',
#    'highlight': ['forests within the range of the northern spotted owl (Strix occidentalis caurina;',
#     'the northern spotted owl (Strix occidentalis caurina; USDA Forest',
#     'Strix occidentalis caurina; USDA Forest Service and USDI Bureau of'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Forest Research',
#    'title': 'Structure and yield of two-aged stands on the Willamette National Forest, Oregon: implications for green tree retention'},
#   {'URL': 'http://doi.wiley.com/10.1002/jwmg.21173',
#    '_gddid': '5c86712b1faed65548992b79',
#    'authors': 'Johnston, Aaron N.; Moskal, L. Monika',
#    'coverDate': '2017 01',
#    'doi': '10.1002/jwmg.21173',
#    'highlight': ['evolution of mapping habitat for northern spotted owls (Strix occidentalis caurina):',
#     'northern spotted owls (Strix occidentalis caurina): a comparison',
#     'Strix occidentalis caurina): a comparison of photo-interpreted, Landsat-based,'],
#    'publisher': 'Wiley',
#    'pubname': 'The Journal of Wildlife Management',
#    'title': 'High-resolution habitat modeling with airborne LiDAR for red tree voles'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1474-919X.2008.00864.x',
#    '_gddid': '58b163becf58f16606917449',
#    'authors': 'MACLEAN, MAIREAD M.; CARSLAKE, DAVID J.; EVANS, MATTHEW R.; TOWNLEY, STUART; HODGSON, DAVID J.',
#    'coverDate': '2008 08',
#    'doi': '10.1111/j.1474-919X.2008.00864.x',
#    'highlight': ['1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75: 601–607. Lande, R., Engen,'],
#    'publisher': 'Wiley',
#    'pubname': 'Ibis',
#    'title': 'The usefulness of sensitivity analysis for predicting the effects of cat predation on the population dynamics of their avian prey'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/B978008045337809001X',
#    '_gddid': '5875607fcf58f15f780a7479',
#    'authors': '',
#    'coverDate': '2010',
#    'doi': '10.1016/B978-0-08-045337-8.09001-X',
#    'highlight': ['2:253 striped polecats 3:84–85 Strix nebulosa 2:226 Strix occidentalis caurina',
#     '3:84–85 Strix nebulosa 2:226 Strix occidentalis caurina 1:382–383',
#     'Strix occidentalis caurina 1:382–383 Strix occidentalis lucida 1:382'],
#    'publisher': 'Elsevier',
#    'pubname': 'Encyclopedia of Animal Behavior',
#    'title': 'Subject Index'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0006320711002096',
#    '_gddid': '57a7a4d9cf58f145121abd80',
#    'authors': 'Van Lanen, Nicholas J.; Franklin, Alan B.; Huyvaert, Kathryn P.; Reiser, Raoul F.; Carlson, Peter C.',
#    'coverDate': 'September 2011',
#    'doi': '10.1016/j.biocon.2011.05.011',
#    'highlight': ['Interference Exclusion  abstract The northern spotted owl (Strix occidentalis caurina)',
#     'Exclusion  abstract The northern spotted owl (Strix occidentalis caurina) is a controversial',
#     'Strix occidentalis caurina) is a controversial species in the Paciﬁc',
#     'threats to populations of northern spotted owls (Strix occidentalis caurina)',
#     'northern spotted owls (Strix occidentalis caurina) has been',
#     'Strix occidentalis caurina) has been the focus of intense study over',
#     'Monitoring the Population Ecology of Spotted Owls (Strix occidentalis caurina)',
#     'Ecology of Spotted Owls (Strix occidentalis caurina) in Northwestern',
#     'Strix occidentalis caurina) in Northwestern California: Annual Results,',
#     'Barred Owls (Strix varia) and Northern Spotted Owls (Strix occidentalis caurina)',
#     'Northern Spotted Owls (Strix occidentalis caurina) in Northwestern',
#     'Strix occidentalis caurina) in Northwestern California with a Playback',
#     'Strangers by Male Territorial Northern Spotted Owls (Strix occidentalis caurina).',
#     'Northern Spotted Owls (Strix occidentalis caurina). M.S.',
#     'Strix occidentalis caurina). M.S. Thesis, Humboldt State University,'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Who hits and hoots at whom? Potential for interference competition between barred and northern spotted owls'},
#   {'URL': 'http://doi.wiley.com/10.1002/eap.1644',
#    '_gddid': '5a4a0defcf58f139da5861b2',
#    'authors': 'Reilly, Matthew J.; Elia, Mario; Spies, Thomas A.; Gregory, Matthew J.; Sanesi, Giovanni; Lafortezza, Raffaele',
#    'coverDate': '2017 10',
#    'doi': '10.1002/eap.1644',
#    'highlight': ['USA, and reltionships to the Northern Spotted Owl (Strix occidentalis caurina)',
#     'the Northern Spotted Owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat conservation. Forest Ecology and'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'Cumulative effects of wildfires on forest dynamics in the eastern Cascade Mountains, USA'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079390722D',
#    '_gddid': '57fec2d4cf58f191a41a4108',
#    'authors': 'Ims, Rolf Anker; Rolstad, Jørund; Wegge, Per',
#    'coverDate': '1993',
#    'doi': '10.1016/0006-3207(93)90722-D',
#    'highlight': ['Pacific Northwest USA is the northern spotted owl Strix occidentalis caurina.',
#     'the northern spotted owl Strix occidentalis caurina. This species',
#     'Strix occidentalis caurina. This species is strongly dependent on old'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Predicting space use responses to habitat fragmentation: can voles Microtus oeconomus serve as an experimental model system (EMS) for capercaillie grouse Tetrao urogallus in boreal forest?'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079290967R',
#    '_gddid': '57fec77ecf58f19347db16d9',
#    'authors': '',
#    'coverDate': '1992',
#    'doi': '10.1016/0006-3207(92)90967-R',
#    'highlight': ['3-17.  Information on the current and historical distributions of Strix occidentalis caurina',
#     'historical distributions of Strix occidentalis caurina and its',
#     'Strix occidentalis caurina and its habitats was reviewed in  light'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Effect of down harvesting on nesting success in a colony of the common eider Somateria mollissima in Svalbard F. Mehlum, L. Neilsen & I. Gjertz, Norsk Polarinstitutt Skrifter, 195, 1991, pp 47–50'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0304380008005073',
#    '_gddid': '5814ab6ccf58f132ada89346',
#    'authors': 'Keane, Robert E.; Drury, Stacy A.; Karau, Eva C.; Hessburg, Paul F.; Reynolds, Keith M.',
#    'coverDate': '10 January 2010',
#    'doi': '10.1016/j.ecolmodel.2008.10.022',
#    'highlight': ['2007. Modeling wildﬁre risk to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat in Central Oregon, USA. Forest'],
#    'publisher': 'Elsevier',
#    'pubname': 'Ecological Modelling',
#    'title': 'A method for mapping fire hazard and risk across multiple scales and its application in fire management'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079390135N',
#    '_gddid': '57ffad2fcf58f11d8fc52268',
#    'authors': 'Hanley, Thomas A.',
#    'coverDate': '1993',
#    'doi': '10.1016/0006-3207(93)90135-N',
#    'highlight': ['1981; Meslow et al., 1981). The northern spotted owl Strix occidentalis caurina',
#     'The northern spotted owl Strix occidentalis caurina was an',
#     'Strix occidentalis caurina was an early focal species there (Forsman,',
#     'E. D. (1992). Dependence of northern spotted owls Strix occidentalis caurina',
#     'of northern spotted owls Strix occidentalis caurina on old-growth',
#     'Strix occidentalis caurina on old-growth forests in the western USA.'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Balancing economic development, biological conservation, and human culture: The sitka black-tailed deer Odocoileus hemionus sitkensis as an ecological indicator'},
#   {'URL': 'http://doi.wiley.com/10.2193/0091-7648(2006)34[899:IPACOC]2.0.CO;2',
#    '_gddid': '57c0f1d3cf58f133f0282270',
#    'authors': 'Irwin, Larry L.',
#    'coverDate': 'October 2006',
#    'doi': '10.2193/0091-7648(2006)34[899:IPACOC]2.0.CO;2',
#    'highlight': ['habitat use and behavior. As the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) is an',
#     'Strix occidentalis caurina) is an indicator of the extent and health'],
#    'publisher': 'Wiley',
#    'pubname': 'Wildlife Society Bulletin',
#    'title': 'Imperfect Pasture: A Century of Change at the National Elk Refuge in Jackson Hole, Wyoming , Bruce Smith, Eric Cole, and David Dobkin. 2004. 135 pp. Grand Teton Natural History Association, Moose, Wyoming, USA. $14.95 (softcover).'},
#   {'URL': 'http://doi.wiley.com/10.2193/0091-7648(2004)032[1333:IMOMHF]2.0.CO;2',
#    '_gddid': '57c0f8d7cf58f1362bbe9133',
#    'authors': 'Buchanan, Joseph B.',
#    'coverDate': 'December 2004',
#    'doi': '10.2193/0091-7648(2004)032[1333:IMOMHF]2.0.CO;2',
#    'highlight': ['adequate?  1333  Joseph B. Buchanan  When the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) was listed',
#     'Strix occidentalis caurina) was listed under the Endangered Species',
#     'Habitat conservation plan for the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) on timberlands',
#     'Strix occidentalis caurina) on timberlands owned by the Murray Pacific',
#     'Habitat management agreement for northern spotted owl (Strix occidentalis caurina)',
#     'for northern spotted owl (Strix occidentalis caurina) dispersal',
#     'Strix occidentalis caurina) dispersal support habitat in the I-90 West'],
#    'publisher': 'Wiley',
#    'pubname': 'Wildlife Society Bulletin',
#    'title': 'Managing habitat for dispersing northern spotted owls—are the current management strategies adequate?'},
#   {'URL': 'http://doi.wiley.com/10.1890/03-0713',
#    '_gddid': '58356fafcf58f182d98b01f7',
#    'authors': 'Marsh, David M.; Thakur, Kanishka A.; Bulka, Kimberley C.; Clarke, L. Blaine',
#    'coverDate': '2004 12',
#    'doi': '10.1890/03-0713',
#    'highlight': ['1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75:601–607. Laurance, W. F.,'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'DISPERSAL AND COLONIZATION THROUGH OPEN FIELDS BY A TERRESTRIAL, WOODLAND SALAMANDER'},
#   {'URL': 'http://www.tandfonline.com/doi/abs/10.1080/08941920701561114',
#    '_gddid': '59545f42cf58f14e12fec64c',
#    'authors': 'Donoghue, Ellen M.; Sturtevant, Victoria E.',
#    'coverDate': '2007 10',
#    'doi': '10.1080/08941920701561114',
#    'highlight': ['Northwest, the listing of the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) as an',
#     'Strix occidentalis caurina) as an endangered species and subsequent'],
#    'publisher': 'Taylor and Francis',
#    'pubname': 'Society & Natural Resources',
#    'title': 'Social Science Constructs in Ecosystem Assessments: Revisiting Community Capacity and Community Resiliency'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0378112704007741',
#    '_gddid': '57921ec1cf58f1037e5f84b1',
#    'authors': 'Hummel, S.; Calkin, D.E.',
#    'coverDate': '21 March 2005',
#    'doi': '10.1016/j.foreco.2004.10.057',
#    'highlight': ['land within the range of the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) was zoned',
#     'Strix occidentalis caurina) was zoned by a 1994 forest management plan'],
#    'publisher': 'Elsevier',
#    'pubname': 'Forest Ecology and Management',
#    'title': 'Costs of landscape silviculture for fire and habitat management'},
#   {'URL': 'http://doi.wiley.com/10.1111/brv.12193',
#    '_gddid': '57918549cf58f18b24906b4e',
#    'authors': 'Thom, Dominik; Seidl, Rupert',
#    'coverDate': 'August 2016',
#    'doi': '10.1111/brv.12193',
#    'highlight': ['(2007). Modeling wildﬁre risk to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat in Central Oregon, USA. Forest',
#     'Northwest, USA, and relationships to Northern Spotted Owl (Strix occidentalis caurina)',
#     'to Northern Spotted Owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat conservation. Forest Ecology and'],
#    'publisher': 'Wiley',
#    'pubname': 'Biological Reviews',
#    'title': 'Natural disturbance impacts on ecosystem services and biodiversity in temperate and boreal forests'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/000632079290969T',
#    '_gddid': '57fe8a8ecf58f17eb2fe734a',
#    'authors': '',
#    'coverDate': '1992',
#    'doi': '10.1016/0006-3207(92)90969-T',
#    'highlight': ['3-17.  Information on the current and historical distributions of Strix occidentalis caurina',
#     'historical distributions of Strix occidentalis caurina and its',
#     'Strix occidentalis caurina and its habitats was reviewed in  light'],
#    'publisher': 'Elsevier',
#    'pubname': 'Biological Conservation',
#    'title': 'Partners in conservation C. R. Smith, Living Bird Quaterly, 10(2), 1991, pp 16–20'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/abs/10.1139/x02-126',
#    '_gddid': '57989690cf58f147b4898221',
#    'authors': 'Ransome, Douglas B; Sullivan, Thomas P',
#    'coverDate': 'November 2002',
#    'doi': '10.1139/x02-126',
#    'highlight': ['prey species. The endangered northern spotted owl (Strix occidentalis caurina',
#     'endangered northern spotted owl (Strix occidentalis caurina (Xantus))',
#     'Strix occidentalis caurina (Xantus)) primarily feeds on G. sabrinus'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Forest Research',
#    'title': 'Short-term population dynamics of Glaucomys sabrinus and Tamiasciurus douglasii in commercially thinned and unthinned stands of coastal coniferous forest'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S0167880903003293',
#    '_gddid': '5799326ccf58f170170f11eb',
#    'authors': 'Tyler, Marnie W.; Peterson, David L.',
#    'coverDate': 'February 2004',
#    'doi': '10.1016/j.agee.2003.09.020',
#    'highlight': ['Brachyramphus marmoratus and northern spotted owl, Strix occidentalis caurina). Landscape',
#     'and northern spotted owl, Strix occidentalis caurina). Landscape',
#     'Strix occidentalis caurina). Landscape structure resulting from these'],
#    'publisher': 'Elsevier',
#    'pubname': 'Agriculture, Ecosystems & Environment',
#    'title': 'Effects of forest policy on landscape pattern of late-seral forest of the Western Olympic Peninsula, Washington'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/abs/10.1139/x11-020',
#    '_gddid': '579c66c3cf58f1a477ab7abc',
#    'authors': 'Ramage, Benjamin S.; O’Hara, Kevin L.; Forrestel, Alison B.',
#    'coverDate': 'April 2011',
#    'doi': '10.1139/x11-020',
#    'highlight': ['primary food source for the northern spotted owl (Strix occidentalis caurina',
#     'the northern spotted owl (Strix occidentalis caurina Xantus',
#     'Strix occidentalis caurina Xantus de Vesey; Courtney et al. 2004). Tree'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Forest Research',
#    'title': 'Forest transformation resulting from an exotic pathogen: regeneration and tanoak mortality in coast redwood stands affected by sudden oak death'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/S016041209700038X',
#    '_gddid': '57eef596cf58f1b97347767e',
#    'authors': 'Gordon, Robert E.; Lacy, James K.; Streeter, James R.',
#    'coverDate': '1997',
#    'doi': '10.1016/S0160-4120(97)00038-X',
#    'highlight': ['Chionanthuspygmaeus  757 000  Northern spotted owl, Strix occidentalis caurina  466',
#     '000  Northern spotted owl, Strix occidentalis caurina  466 900  Grizzly',
#     'Strix occidentalis caurina  466 900  Grizzly bear, Ursus horribilis  414',
#     'deer population in the U.S. 1930-1990.  spotted owl, Strix occidentalis caurina,',
#     '1930-1990.  spotted owl, Strix occidentalis caurina, listed',
#     'Strix occidentalis caurina, listed and served as a resource analyst',
#     'psittacea  1967  D  1  E  Strix occidentalis lucida  1993  U  1  T  Strix occidentalis caurina  1990  D  1  T  Loxioides',
#     'lucida  1993  U  1  T  Strix occidentalis caurina  1990  D  1  T  Loxioides',
#     'Strix occidentalis caurina  1990  D  1  T  Loxioides (=Psittirostra)'],
#    'publisher': 'Elsevier',
#    'pubname': 'Environment International',
#    'title': 'Conservation under the endangered species act'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/abs/10.1139/cjz-2014-0321',
#    '_gddid': '57a29015cf58f15b32f95cbf',
#    'authors': 'Hervieux, D.; Hebblewhite, M.; DeCesare, N.J.; Russell, M.; Smith, K.; Robertson, S.; Boutin, S.',
#    'coverDate': 'February 2015',
#    'doi': '10.1139/cjz-2014-0321',
#    'highlight': ['another endangered species, the Northern Spotted Owl (Strix occidentalis caurina',
#     'the Northern Spotted Owl (Strix occidentalis caurina (Merriam,',
#     'Strix occidentalis caurina (Merriam, 1898)), provided by Franklin et'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Zoology',
#    'title': 'Reply to the comment by Harron on “Widespread declines in woodland caribou ( Rangifer tarandus caribou ) continue in Alberta” 1'},
#   {'URL': 'http://www.tandfonline.com/doi/abs/10.1080/14486563.1995.10648326',
#    '_gddid': '5b1c9b62cf58f16abfac2ece',
#    'authors': 'HOLLAND, GRAHAM; HOLLAND, IAN',
#    'coverDate': '1995 01',
#    'doi': '10.1080/14486563.1995.10648326',
#    'highlight': ['level species, such as the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). The case',
#     'Strix occidentalis caurina). The case of the Spotted Owl is the subject'],
#    'publisher': 'Taylor and Francis',
#    'pubname': 'Australasian Journal of Environmental Management',
#    'title': 'Difficult Decisions About Ordinary Things: Being Ecologically Responsible About Timber Framing'},
#   {'URL': 'http://www.sciencedirect.com/science/article/pii/016953479390241G',
#    '_gddid': '569fc62dcf58f187a425698f',
#    'authors': 'Losos, Elizabeth',
#    'coverDate': 'September 1993',
#    'doi': '10.1016/0169-5347(93)90241-G',
#    'highlight': ['ecosystems. For example, the northern spotted owl (Strix occidentalis caurina)',
# ...
#    'publisher': 'Wiley',
#    'pubname': 'Ecography',
#    'title': 'Competitive exclusion over broad spatial extents is a slow process: evidence and implications for species distribution modeling'},
#   {'URL': 'http://doi.wiley.com/10.1890/02-5084',
#    '_gddid': '5838ac37cf58f1abe824fe84',
#    'authors': 'Zabel, Cynthia J.; Dunk, Jeffrey R.; Stauffer, Howard B.; Roberts, Lynn M.; Mulder, Barry S.; Wright, Adrienne',
#    'coverDate': '2003 08',
#    'doi': '10.1890/02-5084',
#    'highlight': ['currently accepted ideas about Northern Spotted Owl (Strix occidentalis caurina)',
#     'about Northern Spotted Owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat associations in the Klamath Province',
#     'Northern Spotted Owl; owl habitat; predictive models; Strix occidentalis caurina.  INTRODUCTION Wildlife',
#     'habitat; predictive models; Strix occidentalis caurina.  INTRODUCTION Wildlife',
#     'Strix occidentalis caurina.  INTRODUCTION Wildlife biologists have',
#     'and nesting habitat of the Northern Spotted Owl (Strix occidentalis caurina)',
#     'the Northern Spotted Owl (Strix occidentalis caurina) in northwest',
#     'Strix occidentalis caurina) in northwest California. Thesis. Humboldt'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'NORTHERN SPOTTED OWL HABITAT MODELS FOR RESEARCH AND MANAGEMENT APPLICATION IN CALFORNIA (USA)'},
#   {'URL': 'http://doi.wiley.com/10.1890/11-0758.1',
#    '_gddid': '5838d53acf58f1b8b988b74f',
#    'authors': 'Kalies, E. L.; Dickson, B. G.; Chambers, C. L.; Covington, W. W.',
#    'coverDate': '2012 01',
#    'doi': '10.1890/11-0758.1',
#    'highlight': ['federally threatened northern and Mexican spotted owls (Strix occidentalis caurina',
#     'and Mexican spotted owls (Strix occidentalis caurina and S.',
#     'Strix occidentalis caurina and S. o. lucida; Rosenberg et al. 2003,'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecological Applications',
#    'title': 'Community occupancy responses of small mammals to restoration treatments in ponderosa pine forests, northern Arizona, USA'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1365-2656.2009.01534.x',
#    '_gddid': '57126b07cf58f1415fb15088',
#    'authors': 'Hawkes, Colin',
#    'coverDate': 'September 2009',
#    'doi': '10.1111/j.1365-2656.2009.01534.x',
#    'highlight': ['metapopulation models for the northern spotted owl Strix occidentalis caurina',
#     'the northern spotted owl Strix occidentalis caurina where the',
#     'Strix occidentalis caurina where the smallest population unit was the',
#     '(1988) Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia,',
#     'Strix occidentalis caurina). Oecologia, 75, 601–607. Lindstrom, T.,'],
#    'publisher': 'Wiley',
#    'pubname': 'Journal of Animal Ecology',
#    'title': 'Linking movement behaviour, dispersal and population processes: is individual variation a key?'},
#   {'URL': 'http://www.bioone.org/doi/abs/10.2193/2008-430',
#    '_gddid': '572c6ed4cf58f10834d0b3f1',
#    'authors': 'Chinnadurai, Sathya K.; Millspaugh, Joshua J.; Matthews, Wayne S.; Canter, Kirsten; Slotow, Rob; Washburn, Brian E.; Woods, Rami J.',
#    'coverDate': 'August 2009',
#    'doi': '10.2193/2008-430',
#    'highlight': ['measures of disturbance in the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Conservation',
#     'Strix occidentalis caurina). Conservation Biology 11:1019–1022. Wasser,'],
#    'publisher': 'Wiley',
#    'pubname': 'Journal of Wildlife Management',
#    'title': 'Validation of Fecal Glucocorticoid Metabolite Assays for South African Herbivores'},
#   {'URL': 'http://doi.wiley.com/10.1046/j.1523-1739.2001.015002488.x',
#    '_gddid': '571b88bccf58f145bdd05bd2',
#    'authors': 'Harding, Elaine K.; Crone, Elizabeth E.; Elderd, Bret D.; Hoekstra, Jonathan M.; McKerrow, Alexa J.; Perrine, John D.; Regetz, Jim; Rissler, Leslie J.; Stanley, Amanda G.; Walters, Eric L.; Group, Nceas Habitat Conservation Plan Wor',
#    'coverDate': 'April 2001',
#    'doi': '10.1046/j.1523-1739.2001.015002488.x',
#    'highlight': ['borealis Gopherus agassizii Vulpes macrotis mutica Strix occidentalis caurina',
#     'Vulpes macrotis mutica Strix occidentalis caurina Brachyramphus',
#     'Strix occidentalis caurina Brachyramphus marmoratus Polioptila californica',
#     'old-growth forest inhabited by Northern Spotted Owls (Strix occidentalis caurina)',
#     'Northern Spotted Owls (Strix occidentalis caurina) and Marbled',
#     'Strix occidentalis caurina) and Marbled Murrelets in coastal Oregon.'],
#    'publisher': 'Wiley',
#    'pubname': 'Conservation Biology',
#    'title': 'The Scientific Foundations of Habitat Conservation Plans: a Quantitative Assessment'},
#   {'URL': 'http://doi.wiley.com/10.1111/ibi.12465',
#    '_gddid': '58991c37cf58f151df692f24',
#    'authors': 'Staggenborg, Julia; Schaefer, Martin H.; Stange, Christian; Naef-Daenzer, Beat; Grüebler, Martin U.',
#    'coverDate': '2017 02',
#    'doi': '10.1111/ibi.12465',
#    'highlight': ['and habitat-use patterns of Northern Spotted Owls (Strix occidentalis caurina).',
#     'Northern Spotted Owls (Strix occidentalis caurina). Can.',
#     'Strix occidentalis caurina). Can. J. Zool. 73: 433–439. Zuberogoitia,'],
#    'publisher': 'Wiley',
#    'pubname': 'Ibis',
#    'title': 'Time and travelling costs during chick rearing in relation to habitat quality in Little Owls Athene noctua'},
#   {'URL': 'http://www.nrcresearchpress.com/doi/10.1139/cjz-2017-0280',
#    '_gddid': '5c3e6d6d1faed655488cd36e',
#    'authors': 'Chang, Alexander M.; Wiebe, Karen L.',
#    'coverDate': 'June 2018',
#    'doi': '10.1139/cjz-2017-0280',
#    'highlight': ['and habitat-use patterns of northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Can.',
#     'Strix occidentalis caurina). Can. J. Zool. 73(3): 433–439. doi:10.1139/z95-049.  Can.'],
#    'publisher': 'Canadian Science Publishing',
#    'pubname': 'Canadian Journal of Zoology',
#    'title': 'Movement patterns and home ranges of male and female Snowy Owls ( Bubo scandiacus ) wintering on the Canadian prairies'},
#   {'URL': 'http://doi.wiley.com/10.1111/nrm.12056',
#    '_gddid': '5895209bcf58f1b880256f6c',
#    'authors': 'MARCOT, BRUCE G.; SINGLETON, PETER H.; SCHUMAKER, NATHAN H.',
#    'coverDate': '2015 02',
#    'doi': '10.1111/nrm.12056',
#    'highlight': ['threatened species, the Northern Spotted Owl (NSO; Strix occidentalis caurina)',
#     'Northern Spotted Owl (NSO; Strix occidentalis caurina) in Washington,',
#     'Strix occidentalis caurina) in Washington, USA. We explored sensitivity',
#     'threatened populations of Northern Spotted Owls (NSO; Strix occidentalis caurina)',
#     'Northern Spotted Owls (NSO; Strix occidentalis caurina) in a suite',
#     'Strix occidentalis caurina) in a suite of hypothetical landscapes varying',
#     'Revised Recovery Plan for the Northern Spotted Owl (Strix occidentalis caurina),',
#     'the Northern Spotted Owl (Strix occidentalis caurina), U.S.',
#     'Strix occidentalis caurina), U.S. Fish and Wildlife Service, Portland,'],
#    'publisher': 'Wiley',
#    'pubname': 'Natural Resource Modeling',
#    'title': 'ANALYSIS OF SENSITIVITY AND UNCERTAINTY IN AN INDIVIDUAL-BASED MODEL OF A THREATENED WILDLIFE SPECIES'},
#   {'URL': 'http://doi.wiley.com/10.1890/03-8021',
#    '_gddid': '5836a510cf58f11ab52cf9b9',
#    'authors': 'Ries, Leslie; Sisk, Thomas D.',
#    'coverDate': '2004 11',
#    'doi': '10.1890/03-8021',
#    'highlight': ['and habitat-use patterns of northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Canadian',
#     'Strix occidentalis caurina). Canadian Journal of Zoology 73:433–439.  APPENDIX Information'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'A PREDICTIVE MODEL OF EDGE EFFECTS'},
#   {'URL': 'http://doi.wiley.com/10.1111/j.1365-294X.2012.05605.x',
#    '_gddid': '580ad3dfcf58f10e1289d2c0',
#    'authors': 'HILMO, OLGA; LUNDEMO, SVERRE; HOLIEN, HÅKON; STENGRUNDET, KIRSTI; STENØIEN, HANS K.',
#    'coverDate': '2012 07',
#    'doi': '10.1111/j.1365-294X.2012.05605.x',
#    'highlight': ['population bottlenecks in northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Conservation',
#     'Strix occidentalis caurina). Conservation Genetics, 11, 1013– 1021. Ga¨rdenfors'],
#    'publisher': 'Wiley',
#    'pubname': 'Molecular Ecology',
#    'title': 'Genetic structure in a fragmented Northern Hemisphere rainforest: large effective sizes and high connectivity among populations of the epiphytic lichen Lobaria pulmonaria'},
#   {'URL': 'http://doi.wiley.com/10.2193/0084-0173(2006)163[1:SATIDO]2.0.CO;2',
#    '_gddid': '57bf393ecf58f15a54db60ce',
#    'authors': 'ANTHONY, ROBERT G.; FORSMAN, ERIC D.; FRANKLIN, ALAN B.; ANDERSON, DAVID R.; BURNHAM, KENNETH P.; WHITE, GARY C.; SCHWARZ, CARL J.; NICHOLS, JAMES D.; HINES, JAMES E.; OLSON, GAIL S.; ACKERS, STEVEN H.; ANDREWS, LAWRENCE S.; BISWELL, BRIAN L.; CARLSON, PETER C.; DILLER, LOWELL V.; DUGGER, KATIE M.; FEHRING, KATHERINE E.; FLEMING, TRACY L.; GERHARDT, RICHARD P.; GREMEL, SCOTT A.; GUTIÉRREZ, R. J.; HAPPE, PATTI J.; HERTER, DALE R.; HIGLEY, J. MARK; HORN, ROBERT B.; IRWIN, LARRY L.; LOSCHL, PETER J.; REID, JANICE A.; SOVERN, STAN G.',
#    'coverDate': 'July 2006',
#    'doi': '10.2193/0084-0173(2006)163[1:SATIDO]2.0.CO;2',
#    'highlight': ['analyzed demographic data from northern spotted owls (Strix occidentalis caurina)',
#     'northern spotted owls (Strix occidentalis caurina) from 14',
#     'Strix occidentalis caurina) from 14 study areas in Washington, Oregon,',
#     'capture–resighting, demography, fecundity, northern spotted owls, Strix occidentalis caurina,',
#     'northern spotted owls, Strix occidentalis caurina, survival',
#     'Strix occidentalis caurina, survival rates. 2 Wildlife Monographs \x15',
#     '\x15 163   Estodo y Tendencias en la Demografia del Strix occidentalis caurina,',
#     'Tendencias en la Demografia del Strix occidentalis caurina, 1985–2003 RESUMEN Analizamos',
#     'Strix occidentalis caurina, 1985–2003 RESUMEN Analizamos datos demogra´',
#     'datos demogra´ ficos de bu´ hos moteados norten˜ os (Strix occidentalis caurina)',
#     'hos moteados norten˜ os (Strix occidentalis caurina) de catorce',
#     'Strix occidentalis caurina) de catorce a´ reas de estudio en los estados',
#     'Effecitiveness Monitoring Plan (Plan Monitor de Eficacia) para Strix occidentalis caurina',
#     'Monitor de Eficacia) para Strix occidentalis caurina bajo el',
#     'Strix occidentalis caurina bajo el Northwest Forest Plan (Plan Forestal',
#     '(3) la presencia de Strix varia en territorios de Strix occidentalis caurina,',
#     'varia en territorios de Strix occidentalis caurina, (4) el',
#     'Strix occidentalis caurina, (4) el efecto an˜ o par/impar. Estas fluctuaciones',
#     'relacio´ n entre NPV y la proporcio´ n de territorios de Strix occidentalis caurina',
#     'proporcio´ n de territorios de Strix occidentalis caurina donde se',
#     'Strix occidentalis caurina donde se detectaba la presencia de Strix',
#     'haber tenido un efecto positivo en la demografı´a de Strix occidentalis caurina.',
#     'positivo en la demografı´a de Strix occidentalis caurina. Las poblaciones',
#     'Strix occidentalis caurina. Las poblaciones que no prosperaban se encontraban',
#     'mographiques des chouettes tachete´ es septentrionales (Strix occidentalis caurina)',
#     'tachete´ es septentrionales (Strix occidentalis caurina) de 14',
#     'Strix occidentalis caurina) de 14 secteurs d’e´ tude dans Washington,',
#     'Forsman. 1992. Dependence of northern spotted owls (Strix occidentalis caurina)',
#     'northern spotted owls (Strix occidentalis caurina) on old-growth',
#     'Strix occidentalis caurina) on old-growth forests in the western United',
#     'analysis to identify sex of northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Journal',
#     'Strix occidentalis caurina). Journal of Raptor Research 30:18–122. Forsman,',
#     '1988. Demographic models of the northern spotted owl (Strix occidentalis caurina).',
#     'the northern spotted owl (Strix occidentalis caurina). Oecologia',
#     'Strix occidentalis caurina). Oecologia 75:601–607. ———. 1991. Population'],
#    'publisher': 'Wiley',
#    'pubname': 'Wildlife Monographs',
#    'title': 'Status and Trends in Demography of Northern Spotted Owls, 1985–2003'},
#   {'URL': 'http://doi.wiley.com/10.1111/mec.13642',
#    '_gddid': '57dbbba7cf58f1ac99a00bda',
#    'authors': 'Abbott, Richard J.; Barton, Nicholas H.; Good, Jeffrey M.; Wayne, Robert K.; Shaffer, H. Bradley',
#    'coverDate': '2016 06',
#    'doi': '10.1111/mec.13642',
#    'highlight': ['category. For example, the northern spotted owl (Strix occidentalis caurina)',
#     'the northern spotted owl (Strix occidentalis caurina) is a species',
#     'Strix occidentalis caurina) is a species listed under the ESA which'],
#    'publisher': 'Wiley',
#    'pubname': 'Molecular Ecology',
#    'title': 'Hybridization and endangered species protection in the molecular era'},
#   {'URL': 'http://doi.wiley.com/10.1002/ecy.1598',
#    '_gddid': '58667c16cf58f106aebea1c5',
#    'authors': 'Rossman, Sam; Yackulic, Charles B.; Saunders, Sarah P.; Reid, Janice; Davis, Ray; Zipkin, Elise F.',
#    'coverDate': '2016 12',
#    'doi': '10.1002/ecy.1598',
#    'highlight': ['in the continued decline of northern spotted owls (Strix\xa0occidentalis caurina;',
#     'northern spotted owls (Strix\xa0occidentalis caurina; Dugger',
#     'Strix\xa0occidentalis caurina; Dugger et\xa0al. 2016). Yet basic understanding'],
#    'publisher': 'Wiley',
#    'pubname': 'Ecology',
#    'title': 'Dynamic N -occupancy models: estimating demographic rates and local abundance from detection-nondetection data'},
#   {'URL': 'https://www.sciencedirect.com/science/article/pii/S0378112716312919',
#    '_gddid': '5ad4f301cf58f121e64d45c3',
#    'authors': 'Hagmann, R. Keala; Johnson, Debora L.; Johnson, K. Norman',
#    'coverDate': '1 April 2017',
#    'doi': '10.1016/j.foreco.2016.12.029',
#    'highlight': ['currently be utilized by northern spotted owl (NSO, Strix occidentalis caurina).',
#     'northern spotted owl (NSO, Strix occidentalis caurina). Populations',
#     'Strix occidentalis caurina). Populations of this threatened subspecies',
#     'Northwest, USA, and relationships to northern spotted owl (Strix occidentalis caurina)',
#     'to northern spotted owl (Strix occidentalis caurina) habitat',
#     'Strix occidentalis caurina) habitat conservation. For. Ecol. Manage.',
#     'Revised Recovery Plan for the Northern Spotted Owl (Strix occidentalis caurina).',
#     'the Northern Spotted Owl (Strix occidentalis caurina). USDI',
#     'Strix occidentalis caurina). USDI Fish and Wildlife Service, Portland,'],
#    'publisher': 'Elsevier',
#    'pubname': 'Forest Ecology and Management',
#    'title': 'Historical and current forest conditions in the range of the Northern Spotted Owl in south central Oregon, USA'},
#   {'URL': 'http://doi.wiley.com/10.1002/jwmg.21112',
#    '_gddid': '5c86712b1faed65548992b90',
#    'authors': 'Bond, Monica L.; Bradley, Curt; Lee, Derek E.',
#    'coverDate': '2016 09',
#    'doi': '10.1002/jwmg.21112',
#    'highlight': ['and habitat-use patterns of northern spotted owls (Strix occidentalis caurina).',
#     'northern spotted owls (Strix occidentalis caurina). Canadian',
#     'Strix occidentalis caurina). Canadian Journal of Zoology 73:433–439. Zabel,'],
#    'publisher': 'Wiley',
#    'pubname': 'The Journal of Wildlife Management',
#    'title': 'Foraging habitat selection by California spotted owls after fire'}],
#  'Processing Metadata': {'Date Processed': '2019-07-01T22:19:20.970325',
#   'Number Documents': 572,
#   'Search Term': 'Strix occidentalis caurina',
#   'Search URL': 'https://geodeepdive.org/api/snippets?full_results&clean&term=Strix occidentalis caurina',
#   'Status': 'Success'}}
