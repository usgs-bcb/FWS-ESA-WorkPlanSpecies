# %% [markdown]
# Another potentially useful connection from the work plan species are to the terrestrial vertebrates that have been modeled and mapped under the Gap Analysis Project. GAP species include mapped range and habitats (ecological systems classification of the GAP Land Cover 2001 product) along with a set of habitat relationship parameters used in the modeling process, associated scientific references, and other details that may prove useful in working with the species status assessment process.

# %%
import requests
import bispy
import json
from IPython.display import display
from joblib import Parallel, delayed

gap = bispy.gap.Gap()
bis_utils = bispy.bis.Utils()

import helperfunctions

# %%
# Open up the cached workplan species
with open("cache/workplan_species.json", "r") as f:
    workplan_species = json.loads(f.read())

# %%
# Gap only models mammals, birds, reptiles, and amphibians, so restrict the list to just those guilds
possible_gap_species = [s for s in workplan_species if s["Guild"] in ["Birds","Mammals","Reptiles","Amphibians"]]
lookup_name_list = helperfunctions.name_list(possible_gap_species)

# %% [markdown]
# # Note
# There is a problem I've not been able to track down with parallel processing the GAP species query function, so the following codeblock processes the name list serially. It records only the matched names and reports on those names not found.

# %%
# %%time
gap_results = list()
for name, name_source in lookup_name_list:
    gap_spp = gap.gap_species_search(name)
    if gap_spp["Processing Metadata"]["Summary Result"] == "Not Matched":
        print(name, name_source)
    else:
        gap_results.append(gap_spp)
# Out:
# Batrachoseps wrighti Lookup Name
# Lagopus leucura rainierensis Lookup Name
# Monarcha takatsukasae Lookup Name
# Bufo microscaphus microscaphus Lookup Name
# Eurycea sp. Lookup Name
# Sistrurus catenatus edwardsii Lookup Name
# Deirochelys reticularia miaria Lookup Name
# Alces alces andersoni Lookup Name
# Spilogale putorius interrupta Lookup Name
# Pterodroma hasitata Lookup Name
# Grus canadensis pratensis Lookup Name
# Ammodramus maritimus macgillivraii Lookup Name
# Macroclemys temmincki Lookup Name
# Eumeces egregius insularis Lookup Name
# Eumeces egregius egregius Lookup Name
# Diadophis punctatus acricus Lookup Name
# Stilosoma extenuatum Lookup Name
# Anaxyrus boreas boreas Lookup Name
# picoides arcticus Lookup Name
# Lagopus leucura altipetens Lookup Name
# Gulo gulo luscus Lookup Name
# Odobenus rosmarus divergens Lookup Name
# picoides arcticus Lookup Name
# Charina bottae umbratica Lookup Name
# Cnemidophorus inornatus arizonae Valid ITIS Scientific Name
# Sistrurus tergeminus edwardsii Valid ITIS Scientific Name
# Alces americanus americanus Valid ITIS Scientific Name
# Eurycea wallacei Valid ITIS Scientific Name
# Pekania pennanti pennanti Valid ITIS Scientific Name
# CPU times: user 7.86 s, sys: 699 ms, total: 8.56 s
# Wall time: 3min 21s

# %%
# Cache the array of retrieved documents and return/display a random sample for verification
display(bis_utils.doc_cache("cache/gap.json", gap_results))
# Out:
# {'Doc Cache File': 'cache/gap.json',
#  'Document Number 43': {'GAP Species': {'CommonName': 'Fisher',
#    'GAP Habitat Map File Size': 92208495,
#    'GAP Habitat Map Item': 'https://www.sciencebase.gov/catalog/item/58fa685be4b0b7ea5452587f',
#    'GAP Habitat Map Last Updated': '2019-02-08T13:17:39.152-07:00',
#    'GAP Habitat Map WMS': 'https://www.sciencebase.gov/geoserver/CONUS_HabMap_2001/wms?service=WMS&version=1.1.0&request=GetCapabilities',
#    'GAP ITIS Information': {'hierarchySoFarWRanks': {'Class': 'Mammalia',
#      'Family': 'Mustelidae',
#      'Genus': 'Martes',
#      'Infraclass': 'Eutheria',
#      'Infrakingdom': 'Deuterostomia',
#      'Infraphylum': 'Gnathostomata',
#      'Kingdom': 'Animalia',
#      'Order': 'Carnivora',
#      'Phylum': 'Chordata',
#      'Species': 'Martes pennanti',
#      'Subclass': 'Theria',
#      'Subfamily': 'Mustelinae',
#      'Subkingdom': 'Bilateria',
#      'Suborder': 'Caniformia',
#      'Subphylum': 'Vertebrata',
#      'Superclass': 'Tetrapoda'}},
#    'GAP ITIS Information URL': 'https://www.sciencebase.gov/catalog/file/get/58fa685be4b0b7ea5452587f?f=__disk__1a%2F05%2F09%2F1a050918a9b364a0550d244ddf17f57305db21d6',
#    'GAP Modeling Database Parameters': {'doi': 'https://doi.org/10.5066/F7Q81BF7',
#     'habitat_description': 'M. pennant inhabits coniferous or mixed forests, with high canopy cover (>50%), avoiding open areas, scrub, and hardwood forests. Forest structure is a more powerful indicator of fisher presence than is composition, with snag and stump abundance, coarse woody debris, large diameter trees, and a diversity of tree diameters all positively correlated with fisher use.',
#     'input_layers': {'AuxEcoSys': 'https://doi.org/10.5066/F7959GF5',
#      'PrimEcoSys': 'https://doi.org/10.5066/F7959GF5',
#      'Region': 'https://doi.org/10.5066/F77H1HGT',
#      'hucs': 'https://doi.org/10.5066/F7DZ0754',
#      'intEdgeEcoWidth': {'F/O + Shrubland/Woodland': 'https://doi.org/10.5066/F7T43RZ7',
#       'Forest/Open Ecotone Only': 'https://doi.org/10.5066/F7XW4HPN'},
#      'intElevMax': 'https://doi.org/10.5066/F72N515B',
#      'intElevMin': 'https://doi.org/10.5066/F72N515B',
#      'intFromBuffFW': 'https://doi.org/10.5066/F7JM28J1',
#      'intFromBuffOW': 'https://doi.org/10.5066/F7JM28J1',
#      'intFromBuffWV': 'https://doi.org/10.5066/F7JM28J1',
#      'intIntoBuffOW': 'https://doi.org/10.5066/F7JM28J1',
#      'intIntoBuffWV': 'https://doi.org/10.5066/F7JM28J1',
#      'intPercentCanopy': 'https://doi.org/10.5066/F7DZ0754',
#      'intSlopeMax': 'https://doi.org/10.5066/F75D8QQF',
#      'intSlopeMin': 'https://doi.org/10.5066/F75D8QQF',
#      'strAvoid': 'https://doi.org/10.5066/F7PC318R',
#      'strEdgeType': {'F/O + Shrubland/Woodland': 'https://doi.org/10.5066/F7T43RZ7',
#       'Forest/Open Ecotone Only': 'https://doi.org/10.5066/F7XW4HPN'},
#      'strForIntBuffer': 'https://doi.org/10.5066/F7XW4HPN',
#      'strSalinity': 'https://doi.org/10.5066/F7JM28J1',
#      'strStreamVel': 'https://doi.org/10.5066/F7JM28J1',
#      'strUseForInt': 'https://doi.org/10.5066/F7XW4HPN',
#      'ysnHydroFW': 'https://doi.org/10.5066/F7JM28J1',
#      'ysnHydroOW': 'https://doi.org/10.5066/F7JM28J1',
#      'ysnHydroWV': 'https://doi.org/10.5066/F7JM28J1',
#      'ysnUrbanExclude': 'https://doi.org/10.5066/F7PC318R',
#      'ysnUrbanInclude': 'https://doi.org/10.5066/F7PC318R'},
#     'models': {'mFISHx-y1': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[4609,
#         'Northern Rocky Mountain Mesic Montane Mixed Conifer Forest'],
#        [9306, 'North Pacific Hardwood-Conifer Swamp'],
#        [9304, 'Northern Rocky Mountain Conifer Swamp'],
#        [4338,
#         'North Pacific Lowland Mixed Hardwood-Conifer Forest and Woodland'],
#        [4318, 'Mediterranean California Red Fir Forest'],
#        [4522,
#         'North Pacific Maritime Dry-Mesic Douglas-fir-Western Hemlock Forest'],
#        [4528,
#         'Southern Rocky Mountain Dry-Mesic Montane Mixed Conifer Forest and Woodland'],
#        [4527, 'Rocky Mountain Lodgepole Pine Forest'],
#        [4324, 'Inter-Mountain Basins Aspen-Mixed Conifer Forest and Woodland'],
#        [4604, 'North Pacific Hypermaritime Sitka Spruce Forest'],
#        [4611, 'Rocky Mountain Subalpine Mesic Spruce-Fir Forest and Woodland'],
#        [4610,
#         'Southern Rocky Mountain Mesic Montane Mixed Conifer Forest and Woodland'],
#        [4607, 'North Pacific Mesic Western Hemlock-Silver Fir Forest'],
#        [4603,
#         'Mediterranean California Mesic Mixed Conifer Forest and Woodland'],
#        [4613,
#         'North Pacific Hypermaritime Western Red-cedar-Western Hemlock Forest'],
#        [4602, 'East Cascades Mesic Montane Mixed-Conifer Forest and Woodland'],
#        [4601, 'California Coastal Redwood Forest'],
#        [4606,
#         'North Pacific Maritime Mesic-Wet Douglas-fir-Western Hemlock Forest'],
#        [9832, 'Rocky Mountain Subalpine-Montane Riparian Woodland'],
#        [9825, 'Rocky Mountain Lower Montane Riparian Woodland and Shrubland'],
#        [9824,
#         'Northern Rocky Mountain Lower Montane Riparian Woodland and Shrubland']],
#       'Region': 'Northwest',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': 2500,
#       'intElevMin': 0,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': None,
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False},
#      'mFISHx-y2': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[4542, 'Laurentian Jack Pine-Red Pine Forest'],
#        [9308, 'Laurentian-Acadian Alkaline Conifer-Hardwood Swamp'],
#        [4331, 'Appalachian Hemlock-Hardwood Forest'],
#        [4330, 'Central Appalachian Oak and Pine Forest'],
#        [4327, 'Laurentian-Acadian Pine-Hemlock-Hardwood Forest'],
#        [4535, 'Boreal Jack Pine-Black Spruce Forest'],
#        [4326, 'Boreal White Spruce-Fir-Hardwood Forest'],
#        [4323, 'Laurentian-Acadian Northern Pine-(Oak) Forest']],
#       'Region': 'Upper Midwest',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': None,
#       'intElevMin': None,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': None,
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False},
#      'mFISHx-y3': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[9214, 'Laurentian-Acadian Swamp Systems'],
#        [9308, 'Laurentian-Acadian Alkaline Conifer-Hardwood Swamp'],
#        [4331, 'Appalachian Hemlock-Hardwood Forest'],
#        [4330, 'Central Appalachian Oak and Pine Forest'],
#        [4327, 'Laurentian-Acadian Pine-Hemlock-Hardwood Forest'],
#        [4551, 'Acadian-Appalachian Montane Spruce-Fir Forest'],
#        [4333, 'Acadian Low-Elevation Spruce-Fir-Hardwood Forest'],
#        [4612, 'Central and Southern Appalachian Spruce-Fir Forest'],
#        [4323, 'Laurentian-Acadian Northern Pine-(Oak) Forest']],
#       'Region': 'Northeast',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': None,
#       'intElevMin': None,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': None,
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False},
#      'mFISHx-y4': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[4609,
#         'Northern Rocky Mountain Mesic Montane Mixed Conifer Forest'],
#        [9307, 'Northern Pacific Mesic Subalpine Woodland'],
#        [4318, 'Mediterranean California Red Fir Forest'],
#        [4528,
#         'Southern Rocky Mountain Dry-Mesic Montane Mixed Conifer Forest and Woodland'],
#        [4527, 'Rocky Mountain Lodgepole Pine Forest'],
#        [4324, 'Inter-Mountain Basins Aspen-Mixed Conifer Forest and Woodland'],
#        [4604, 'North Pacific Hypermaritime Sitka Spruce Forest'],
#        [4611, 'Rocky Mountain Subalpine Mesic Spruce-Fir Forest and Woodland'],
#        [4610,
#         'Southern Rocky Mountain Mesic Montane Mixed Conifer Forest and Woodland'],
#        [4603,
#         'Mediterranean California Mesic Mixed Conifer Forest and Woodland'],
#        [4601, 'California Coastal Redwood Forest'],
#        [9832, 'Rocky Mountain Subalpine-Montane Riparian Woodland'],
#        [9825, 'Rocky Mountain Lower Montane Riparian Woodland and Shrubland'],
#        [9824,
#         'Northern Rocky Mountain Lower Montane Riparian Woodland and Shrubland']],
#       'Region': 'Southwest',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': 2500,
#       'intElevMin': 0,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': None,
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False},
#      'mFISHx-y5': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[4609,
#         'Northern Rocky Mountain Mesic Montane Mixed Conifer Forest'],
#        [9304, 'Northern Rocky Mountain Conifer Swamp'],
#        [4528,
#         'Southern Rocky Mountain Dry-Mesic Montane Mixed Conifer Forest and Woodland'],
#        [4527, 'Rocky Mountain Lodgepole Pine Forest'],
#        [4324, 'Inter-Mountain Basins Aspen-Mixed Conifer Forest and Woodland'],
#        [4611, 'Rocky Mountain Subalpine Mesic Spruce-Fir Forest and Woodland'],
#        [4610,
#         'Southern Rocky Mountain Mesic Montane Mixed Conifer Forest and Woodland'],
#        [9832, 'Rocky Mountain Subalpine-Montane Riparian Woodland'],
#        [9825, 'Rocky Mountain Lower Montane Riparian Woodland and Shrubland'],
#        [9824,
#         'Northern Rocky Mountain Lower Montane Riparian Woodland and Shrubland']],
#       'Region': 'Great Plains',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': 2500,
#       'intElevMin': 0,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': None,
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False},
#      'mFISHx-y6': {'AuxEcoSys': [],
#       'CommonName': 'Fisher',
#       'Modeler': 'Thomas Laxson',
#       'PrimEcoSys': [[4104,
#         'Northeastern Interior Dry Oak Forest-Hardwood Modifier'],
#        [4106, 'Northeastern Interior Dry Oak Forest - Mixed Modifier'],
#        [9803, 'Central Appalachian Riparian - Forest Modifier'],
#        [9802, 'Central Appalachian Floodplain - Forest Modifier'],
#        [4331, 'Appalachian Hemlock-Hardwood Forest'],
#        [4330, 'Central Appalachian Oak and Pine Forest'],
#        [4304,
#         'Northeastern Interior Dry Oak Forest - Virginia/Pitch Pine Modifier'],
#        [4333, 'Acadian Low-Elevation Spruce-Fir-Hardwood Forest'],
#        [4537, 'Southern Appalachian Montane Pine Forest and Woodland'],
#        [4401, 'Southern and Central Appalachian Cove Forest'],
#        [4109, 'Southern and Central Appalachian Oak Forest - Xeric'],
#        [4101, 'Central and Southern Appalachian Northern Hardwood Forest'],
#        [4125, 'Southern and Central Appalachian Oak Forest'],
#        [4126, 'Allegheny-Cumberland Dry Oak Forest and Woodland - Hardwood'],
#        [4127, 'Central and Southern Appalachian Montane Oak Forest'],
#        [4612, 'Central and Southern Appalachian Spruce-Fir Forest'],
#        [9506, 'Southern and Central Appalachian Bog and Fen']],
#       'Region': 'Southeast',
#       'Reviewer': 'Jeff Lonneker',
#       'ScientificName': 'Martes pennanti',
#       'Season': 'y',
#       'SpeciesCode': 'mFISHx',
#       'SubspeciesName': '',
#       'cbxContPatch': True,
#       'intAuxBuff': None,
#       'intContPatchSize': 100,
#       'intEdgeEcoWidth': None,
#       'intElevMax': None,
#       'intElevMin': None,
#       'intFromBuffFW': None,
#       'intFromBuffOW': None,
#       'intFromBuffWV': None,
#       'intIntoBuffFW': None,
#       'intIntoBuffOW': None,
#       'intIntoBuffWV': None,
#       'intPercentCanopy': None,
#       'intSlopeMax': None,
#       'intSlopeMin': None,
#       'memHandModelNotes': 'Optimal conditions: forest tracts of 245 acres (99ha) or more, interconnected with other large areas of suitable habitat; a dense understory of young conifers, shrubs, and herbaceous cover is important in summer.  From NatureServe 2005.  ****Non-Contiguous Patch usage??. Amy Silvano 24jun05',
#       'strAvoid': None,
#       'strEdgeType': None,
#       'strForIntBuffer': None,
#       'strSalinity': None,
#       'strStreamVel': None,
#       'strUseForInt': None,
#       'ysnHandModel': False,
#       'ysnHydroFW': False,
#       'ysnHydroOW': False,
#       'ysnHydroWV': False,
#       'ysnUrbanExclude': False,
#       'ysnUrbanInclude': False}},
#     'references': ['Arthur, S. M., and W. B. Krohn. 1991. Activity patterns, movements, and reproductive ecology of fishers in southcentral Maine. J. Mamm. 72:379-385.',
#      'Hamilton, William J., Jr., and John O. Whitaker, Jr. 1979. Mammals of the eastern United States. Cornell Univ. Press, Ithaca, New York. 346 pp.',
#      'U.S. Forest Service, et al. 1993. Draft supplemental environmental impact statement on management of habitat for late-successional and old-growth forest related species within the range of the northern spotted owl. Published separately is Appendix A:Fores',
#      'Buskirk, S. W. 1992. Conserving circumboreal forests for martens and fishers. Conservation Biology 6:318-320.',
#      "Handley, C. O., Jr. 1991. Mammals. Pages 539-616 in K. Terwilliger, coordinator. Virginia's endangered species:proceedings of a symposium. McDonald and Woodward Publishing Company, Blacksburg, Virginia.",
#      'Buskirk, S. W., et al., editors. 1994. Martens, sables, and fishers:biology and conservation. Cornell. 496 pp.',
#      'Hall, E. R. 1981. The Mammals of North America. Second edition. 2 Volumes. John Wiley and Sons, New York, New York. 1181 p.',
#      'Spahr, R., L. Armstrong, D. Atwood, and M. Rath. 1991. Threatened, endangered, and sensitive species of the Intermountain Region. U.S. Forest Service, Ogden, Utah.',
#      'Kilpatrick, H. J., and P. W. Rego. 1994. Influence of season, sex, and site availability on fisher (MARTES PENNANTI) rest-site selection in the central hardwood forest. Can. J. Zool. 72:1416-1419.',
#      'Meyer, Rachelle. 2007. Martes pennanti. In: Fire Effects Information System, [Online]. U.S. Department of Agriculture, Forest Service, Rocky Mountain Research Station, Fire Sciences Laboratory (Producer). Available: http://www.fs.fed.us/database/feis/ [2012, April 20].',
#      'Powell, R.A. 1981. MARTES PENNANTI. MAMMALIAN SPECIES. AMERICAN SOC. OF MAMMALOGISTS. NO.156:1-6.',
#      "Nowak, R. M. 1991. Walker's mammals of the world. Fifth edition. Vols. I and II. Johns Hopkins Univ. Press, Baltimore. 1629 pp.",
#      'Jones, J. K., Jr., et al. 1992. Revised checklist of North American mammals north of Mexico, 1991. Occas. Pap. Mus., Texas Tech Univ. (146):1-23.',
#      'Thomasma, L. E., T. D. Drummer, and R. O. Peterson. 1991. Testing the habitat suitability index model for the fisher. Wildl. Soc. Bull. 19:291-297.',
#      'Baker, Rollin H. 1983. Michigan mammals. Michigan State University Press. 642 pp.',
#      'Berg, W. E. 1982. Reintroduction of fisher, pine marten, and river otter. Pages 159-173 in G. C. Sanderson, editor. Midwest furbearer management. Proc. Symp. 43rd Midwest Fishand Widlife Conference, Wichita, Kansas.',
#      'Strickland, M. A., et al. 1982. Fisher MARTES PENNANTI. Pages 586-598 in J. A. Chapman and G. A. Feldhamer, editors. Wild mammals of North America:biology, management, and economics. Johns Hopkins Univ. Press, Baltimore.',
#      'Allen, A. W. 1983. Habitat suitability index models:fisher. U.S. Fish and Wildl. Serv. FWS/OBS-82/10.45. 19 pp.',
#      'Powell, R. A. 1982. The fisher: life history, ecology, andbehavior. Univ. Minnesota Press. 217 pp.',
#      'Arthur, S. M. 1988. An evaluation of techniques for capturing and radiocollaring fishers. Wildl. Soc. Bull. 16:417-421.',
#      'Leonard, R. D. 1986. Aspects of reproduction of the fisher, MARTES PENNANTI, in Manitoba. Can. Field-Nat. 100:32-44.',
#      'de Vos, A. 1952. Ecology and management of fisher and marten in Ontario. Tech. Bull. Ontario Dept. Lands For., Wildl. Ser. 1. 90 pp.',
#      'Webster, W. D., J. F. Parnell and W. C. Biggs Jr. 1985. Mammals of the Carolinas, Virginia, and Maryland. The University of North Carolina Press, Chapel Hill, NC.',
#      'Arthur, S. M., W. B. Krohn, and J. R. Gilbert. 1989. Home range characteristics of adult fishers. J. Wildl. Manage. 53:674-679.',
#      'Godin, A.J. 1977. Wild Mammals of New England. Johns Hopkins University Press, Baltimore. 304 pp.',
#      'Ruggiero, L. F., K. B. Aubry, S. W. Buskirk, L. J. Lyon, and W. J. Zielinski, editors. 1994. The scientific basis for conserving forest carnivores in the western United States:American marten, fisher, lynx, and wolverine. USDA Forest Service, General Tech',
#      'Wilson, D. E., and D. M. Reeder (editors). 1993. Mammal Species of the World:a Taxonomic and Geographic Reference. Second Edition. Smithsonian Institution Press, Washington, DC. xviii + 1206 pp.',
#      'Thomas, J. W., et al. 1993. Viability assessments and management considerations for species associated with late-successional and old-growth forests of the Pacific Northwest. The report of the Scientific Analysis Team. USDA Forest Service, Spotted Owl EIS',
#      'Powell, R.A. 1994. Effects of scale on habitat selection and foraging behavior of fishers in winter. Journal of Mammalogy, 75:349-356.',
#      'Banfield, A.W.F. 1974. The mammals of Canada. University of Toronto Press, Toronto.'],
#     'sb_url': 'https://www.sciencebase.gov/catalog/item/58fa685be4b0b7ea5452587f',
#     'taxonomic': {'ELCode': 'AMAJF01020',
#      'Global_SEQ_ID': '103714',
#      'ITIS_TSN': '180560',
#      'common_name': 'Fisher',
#      'gap_code': 'mFISHx',
#      'scientific_name': 'Martes pennanti'}},
#    'GAP Modeling Database Parameters URL': 'https://www.sciencebase.gov/catalog/file/get/58fa685be4b0b7ea5452587f?f=__disk__08%2F3e%2F90%2F083e9083a692a312cc9e365614d000b0ac6d4fbd',
#    'GAP Range Map Item': 'https://www.sciencebase.gov/catalog/item/59f5ebe3e4b063d5d307e239',
#    'GAP Range Map WMS': 'https://www.sciencebase.gov/geoserver/CONUS_Range_2001/wms?service=WMS&version=1.1.0&request=GetCapabilities',
#    'GAP_SpeciesCode': 'mFISHx',
#    'Range Bounding Box': [-124.66825578435517,
#     35.45074007962659,
#     -66.9017614483196,
#     49.38436632907967],
#    'ScientificName': 'Martes pennanti',
#    'doi': 'doi:10.5066/F7Q81BF7',
#    'itis_tsn_validMatch': '180560',
#    'iucn_id_verified': '41651',
#    'nsid_acceptedMatch': '103714'},
#   'Processing Metadata': {'Date Processed': '2019-07-10T16:01:11.374058',
#    'Search URL': "https://www.sciencebase.gov/catalog/items?parentId=527d0a83e4b0850ea0518326&format=json&fields=identifiers,files,webLinks,distributionLinks,dates&filter=itemIdentifier%3D{'key': 'Martes pennanti'}",
#    'Summary Result': 'Exact Match'}},
#  'Number of Documents in Cache': 63}
