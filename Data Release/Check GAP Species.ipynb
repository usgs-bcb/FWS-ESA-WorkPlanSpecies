# %% [markdown]
# Another potentially useful connection from the work plan species are to the terrestrial vertebrates that have been modeled and mapped under the Gap Analysis Project. GAP species include mapped range and habitats (ecological systems classification of the GAP Land Cover 2001 product) along with a set of habitat relationship parameters used in the modeling process, associated scientific references, and other details that may prove useful in working with the species status assessment process.

# %%
import requests
import json
import bispy
from IPython.display import display
from joblib import Parallel, delayed
import random

gap = bispy.gap.Gap()

# %%
# Open up the cached workplan species
with open("cache/workplan_species.json", "r") as f:
    workplan_species = json.loads(f.read())

# %%
# Gap only models mammals, birds, reptiles, and amphibians, so restrict the list to just those guilds
possible_gap_species = [s["Scientific Name"] for s in workplan_species if s["Guild"] in ["Birds","Mammals","Reptiles","Amphibians"]]

# %%
# Use joblib to run multiple requests for SGCN records in parallel via scientific names
gap_results = Parallel(n_jobs=8)(delayed(gap.gap_species_search)(name) for name in possible_gap_species)

# %%
# Dump the GAP records we discovered and packaged to a cache file
# I need to revisit this once I get some things cleared up with taxonomic matching to hopefully find more GAP records
with open("cache/gap.json", "w") as f:
    f.write(json.dumps([g for g in gap_results if g["Processing Metadata"]["Summary Result"] == "Exact Match"], indent=4))

# %%
# Open the file back up and verify
with open("cache/gap.json", "r") as f:
    gap_cache = json.loads(f.read())

print(len(gap_cache))
display(gap_cache[random.randint(0,len(gap_cache)-1)])
# Out:
# 58
# {'GAP Species': {'CommonName': 'Rio Grande Cooter',
#   'GAP Habitat Map File Size': 6050892,
#   'GAP Habitat Map Item': 'https://www.sciencebase.gov/catalog/item/58fe22e3e4b0f87f0854ae79',
#   'GAP Habitat Map Last Updated': '2019-02-08T12:14:55.567-07:00',
#   'GAP Habitat Map WMS': 'https://www.sciencebase.gov/geoserver/CONUS_HabMap_2001/wms?service=WMS&version=1.1.0&request=GetCapabilities',
#   'GAP ITIS Information': {'hierarchySoFarWRanks': {'Class': 'Reptilia',
#     'Family': 'Emydidae',
#     'Genus': 'Pseudemys',
#     'Infrakingdom': 'Deuterostomia',
#     'Infraphylum': 'Gnathostomata',
#     'Kingdom': 'Animalia',
#     'Order': 'Testudines',
#     'Phylum': 'Chordata',
#     'Species': 'Pseudemys gorzugi',
#     'Subfamily': 'Deirochelyinae',
#     'Subkingdom': 'Bilateria',
#     'Suborder': 'Cryptodira',
#     'Subphylum': 'Vertebrata',
#     'Superclass': 'Tetrapoda',
#     'Superfamily': 'Testudinoidea'}},
#   'GAP ITIS Information URL': 'https://www.sciencebase.gov/catalog/file/get/58fe22e3e4b0f87f0854ae79?f=__disk__9b%2F5b%2F2d%2F9b5b2d9ecbbb00acbc509c5e35c66bbfd71b3ed9',
#   'GAP Modeling Database Parameters': {'doi': 'https://doi.org/10.5066/F7JQ0ZGP',
#    'habitat_description': None,
#    'input_layers': {'AuxEcoSys': 'https://doi.org/10.5066/F7959GF5',
#     'PrimEcoSys': 'https://doi.org/10.5066/F7959GF5',
#     'Region': 'https://doi.org/10.5066/F77H1HGT',
#     'hucs': 'https://doi.org/10.5066/F7DZ0754',
#     'intEdgeEcoWidth': {'F/O + Shrubland/Woodland': 'https://doi.org/10.5066/F7T43RZ7',
#      'Forest/Open Ecotone Only': 'https://doi.org/10.5066/F7XW4HPN'},
#     'intElevMax': 'https://doi.org/10.5066/F72N515B',
#     'intElevMin': 'https://doi.org/10.5066/F72N515B',
#     'intFromBuffFW': 'https://doi.org/10.5066/F7JM28J1',
#     'intFromBuffOW': 'https://doi.org/10.5066/F7JM28J1',
#     'intFromBuffWV': 'https://doi.org/10.5066/F7JM28J1',
#     'intIntoBuffOW': 'https://doi.org/10.5066/F7JM28J1',
#     'intIntoBuffWV': 'https://doi.org/10.5066/F7JM28J1',
#     'intPercentCanopy': 'https://doi.org/10.5066/F7DZ0754',
#     'intSlopeMax': 'https://doi.org/10.5066/F75D8QQF',
#     'intSlopeMin': 'https://doi.org/10.5066/F75D8QQF',
#     'strAvoid': 'https://doi.org/10.5066/F7PC318R',
#     'strEdgeType': {'F/O + Shrubland/Woodland': 'https://doi.org/10.5066/F7T43RZ7',
#      'Forest/Open Ecotone Only': 'https://doi.org/10.5066/F7XW4HPN'},
#     'strForIntBuffer': 'https://doi.org/10.5066/F7XW4HPN',
#     'strSalinity': 'https://doi.org/10.5066/F7JM28J1',
#     'strStreamVel': 'https://doi.org/10.5066/F7JM28J1',
#     'strUseForInt': 'https://doi.org/10.5066/F7XW4HPN',
#     'ysnHydroFW': 'https://doi.org/10.5066/F7JM28J1',
#     'ysnHydroOW': 'https://doi.org/10.5066/F7JM28J1',
#     'ysnHydroWV': 'https://doi.org/10.5066/F7JM28J1',
#     'ysnUrbanExclude': 'https://doi.org/10.5066/F7PC318R',
#     'ysnUrbanInclude': 'https://doi.org/10.5066/F7PC318R'},
#    'models': {'rRGCOx-y4': {'AuxEcoSys': [],
#      'CommonName': 'Rio Grande Cooter',
#      'Modeler': 'Ken Boykin',
#      'PrimEcoSys': [[8406, 'Introduced Riparian and Wetland Vegetation'],
#       [9227, 'North American Arid West Emergent Marsh'],
#       [9706, 'Western Great Plains Depressional Wetland Systems'],
#       [9823, 'Western Great Plains Floodplain'],
#       [2102, 'Open Water (Fresh)'],
#       [8504, 'Ruderal Wetland'],
#       [9707, 'Western Great Plains Open Freshwater Depression Wetland'],
#       [9606, 'Rocky Mountain Alpine-Montane Wet Meadow'],
#       [9814, 'Western Great Plains Floodplain Systems'],
#       [9848, 'Western Great Plains Riparian Woodland and Shrubland'],
#       [9835, 'North American Warm Desert Riparian Woodland and Shrubland'],
#       [9833,
#        'North American Warm Desert Lower Montane Riparian Woodland and Shrubland'],
#       [9810, 'Inter-Mountain Basins Greasewood Flat']],
#      'Region': 'Southwest',
#      'Reviewer': 'Jeff Lonneker',
#      'ScientificName': 'Pseudemys gorzugi',
#      'Season': 'y',
#      'SpeciesCode': 'rRGCOx',
#      'SubspeciesName': '',
#      'cbxContPatch': False,
#      'intAuxBuff': None,
#      'intContPatchSize': None,
#      'intEdgeEcoWidth': None,
#      'intElevMax': 1100,
#      'intElevMin': 0,
#      'intFromBuffFW': 30.0,
#      'intFromBuffOW': 30.0,
#      'intFromBuffWV': 0.0,
#      'intIntoBuffFW': 250.0,
#      'intIntoBuffOW': 250.0,
#      'intIntoBuffWV': 0.0,
#      'intPercentCanopy': None,
#      'intSlopeMax': None,
#      'intSlopeMin': None,
#      'memHandModelNotes': None,
#      'strAvoid': None,
#      'strEdgeType': None,
#      'strForIntBuffer': None,
#      'strSalinity': 'Freshwater Only',
#      'strStreamVel': 'Slow Only',
#      'strUseForInt': None,
#      'ysnHandModel': False,
#      'ysnHydroFW': True,
#      'ysnHydroOW': True,
#      'ysnHydroWV': False,
#      'ysnUrbanExclude': False,
#      'ysnUrbanInclude': False},
#     'rRGCOx-y5': {'AuxEcoSys': [],
#      'CommonName': 'Rio Grande Cooter',
#      'Modeler': 'Ken Boykin',
#      'PrimEcoSys': [[8406, 'Introduced Riparian and Wetland Vegetation'],
#       [9227, 'North American Arid West Emergent Marsh'],
#       [9706, 'Western Great Plains Depressional Wetland Systems'],
#       [9823, 'Western Great Plains Floodplain'],
#       [2102, 'Open Water (Fresh)'],
#       [8504, 'Ruderal Wetland'],
#       [9707, 'Western Great Plains Open Freshwater Depression Wetland'],
#       [9606, 'Rocky Mountain Alpine-Montane Wet Meadow'],
#       [9814, 'Western Great Plains Floodplain Systems'],
#       [9848, 'Western Great Plains Riparian Woodland and Shrubland'],
#       [9835, 'North American Warm Desert Riparian Woodland and Shrubland'],
#       [9833,
#        'North American Warm Desert Lower Montane Riparian Woodland and Shrubland'],
#       [9810, 'Inter-Mountain Basins Greasewood Flat']],
#      'Region': 'Great Plains',
#      'Reviewer': 'Jeff Lonneker',
#      'ScientificName': 'Pseudemys gorzugi',
#      'Season': 'y',
#      'SpeciesCode': 'rRGCOx',
#      'SubspeciesName': '',
#      'cbxContPatch': False,
#      'intAuxBuff': None,
#      'intContPatchSize': None,
#      'intEdgeEcoWidth': None,
#      'intElevMax': 1100,
#      'intElevMin': 0,
#      'intFromBuffFW': 30.0,
#      'intFromBuffOW': 30.0,
#      'intFromBuffWV': 0.0,
#      'intIntoBuffFW': 250.0,
#      'intIntoBuffOW': 250.0,
#      'intIntoBuffWV': 0.0,
#      'intPercentCanopy': None,
#      'intSlopeMax': None,
#      'intSlopeMin': None,
#      'memHandModelNotes': None,
#      'strAvoid': None,
#      'strEdgeType': None,
#      'strForIntBuffer': None,
#      'strSalinity': 'Freshwater Only',
#      'strStreamVel': 'Slow Only',
#      'strUseForInt': None,
#      'ysnHandModel': False,
#      'ysnHydroFW': True,
#      'ysnHydroOW': True,
#      'ysnHydroWV': False,
#      'ysnUrbanExclude': False,
#      'ysnUrbanInclude': False}},
#    'references': ['Stebbins, R.C. 2003. A field guide to western reptiles and amphibians.  Third Edition. Houghton Mifflin, Boston.',
#     'Degenhardt, W., Painter, C., and A. Price.  1996. Amphibians and reptiles of New Mexico. University of New Mexico Press, Albuquerque, New Mexico. 429 pages.'],
#    'sb_url': 'https://www.sciencebase.gov/catalog/item/58fe22e3e4b0f87f0854ae79',
#    'taxonomic': {'ELCode': 'ARAAD07070',
#     'Global_SEQ_ID': '103473',
#     'ITIS_TSN': '551766',
#     'common_name': 'Rio Grande Cooter',
#     'gap_code': 'rRGCOx',
#     'scientific_name': 'Pseudemys gorzugi'}},
#   'GAP Modeling Database Parameters URL': 'https://www.sciencebase.gov/catalog/file/get/58fe22e3e4b0f87f0854ae79?f=__disk__d7%2F3b%2F68%2Fd73b688b45126c7707139dca126228619a1b5304',
#   'GAP Range Map Item': 'https://www.sciencebase.gov/catalog/item/59f5e204e4b063d5d307dc1f',
#   'GAP Range Map WMS': 'https://www.sciencebase.gov/geoserver/CONUS_Range_2001/wms?service=WMS&version=1.1.0&request=GetCapabilities',
#   'GAP_SpeciesCode': 'rRGCOx',
#   'Range Bounding Box': [-105.08185976365269,
#    25.837469510783723,
#    -97.09617729362726,
#    33.97175002147884],
#   'ScientificName': 'Pseudemys gorzugi',
#   'doi': 'doi:10.5066/F7JQ0ZGP',
#   'itis_tsn_validMatch': '551766',
#   'iucn_id_verified': '18459',
#   'nsid_acceptedMatch': '103473'},
#  'Processing Metadata': {'Date Processed': '2019-07-01T20:15:40.529005',
#   'Search URL': "https://www.sciencebase.gov/catalog/items?parentId=527d0a83e4b0850ea0518326&format=json&fields=identifiers,files,webLinks,distributionLinks,dates&filter=itemIdentifier%3D{'key': 'Pseudemys gorzugi'}",
#   'Summary Result': 'Exact Match'}}
