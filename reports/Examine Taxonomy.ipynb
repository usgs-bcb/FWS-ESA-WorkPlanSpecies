# %% [markdown]
# This notebook works through the major issues that should likely be considered about the names/records from the original FWS Work Plan list that were not exactly matched to a corresponding record in the Integrated Taxonomic Information System (ITIS), the major taxonomic authority used by FWS. We include a report on names that out process was able to find in the World Register of Marine Species (WoRMS), particularly molluscs that have been addressed in the WoRMS taxonomic review process based on community demand. We also show a report of those ITIS TSNs and names that came from the original FWS Work Plan source where we needed to follow the "Accepted TSN" in ITIS to retrieve the accepted/valid record.
#
# In both of these cases, it may be helpful to

# %%
import json
from IPython.display import display

# %%
with open('../cache/itis.json', 'r') as f:
    itis_species = json.loads(f.read())
    f.close()

with open('../cache/worms.json', 'r') as f:
    worms_species = json.loads(f.read())
    f.close()

# %% [markdown]
# The following codeblock builds two lists. The first is a list of species names from the FWS Work Plan source where our process was unable to find a match in either ITIS or WoRMS. The second is a list where our process did not find a match in ITIS but did find a match in WoRMS. In one of the WoRMS records, the taxonomy is flagged as uncertain, and we provide a link for followup.

# %%
no_taxonomic_match = list()
worms_matches = list()
for name in [i["parameters"]["Scientific Name"] for i in itis_species if i["processing_metadata"]["status_message"] == "Not Matched"]:
    worms_match = next((i for i in worms_species if i["processing_metadata"]["status"] == "success" and i["parameters"]["Scientific Name"] == name), None)
    if worms_match is None:
        no_taxonomic_match.append(name)
    else:
        if worms_match["data"][0]["status"] != "accepted":
            worms_matches.append(
                "{} - {} - http://marinespecies.org/aphia.php?p=taxdetails&id={}".format(
                    name, 
                    worms_match['data'][0]['status'], 
                    worms_match['data'][0]['AphiaID']
                )
            )
        else:
            worms_matches.append(name)
        
print("Names with no match in ITIS or WoRMS")
display(no_taxonomic_match)

print("Names found in WoRMS but not ITIS")
display(worms_matches)
# Out:
# Names with no match in ITIS or WoRMS
# ['Lycaena ferrisi', 'Etheostoma maydeni', 'Euphilotes ancilla cryptica']
# Names found in WoRMS but not ITIS
# ['Monadenia fidelis minor',
#  'Percina kusha',
#  'Boltonia montana - uncertain - http://marinespecies.org/aphia.php?p=taxdetails&id=1124563',
#  'Pyrgulopsis hamlinensis',
#  'Pyrgulopsis anguina',
#  'Pyrgulopsis saxatilis',
#  'Pyrgulopsis peculiaris',
#  'Pyrgulopsis coloradensis',
#  'Pyrgulopsis lata',
#  'Pyrgulopsis fausta',
#  'Pyrgulopsis breviloba',
#  'Pyrgulopsis planulata',
#  'Pyrgulopsis marcida',
#  'Pyrgulopsis hubbsi',
#  'Pyrgulopsis sublata',
#  'Pyrgulopsis landyei',
#  'Pyrgulopsis neritella',
#  'Pyrgulopsis serrata',
#  'Pyrgulopsis turbatrix',
#  'Pyrgulopsis sulcata',
#  'Pyrgulopsis deaconi',
#  'Pyrgulopsis sterilis',
#  'Pyrgulopsis orbiculata',
#  'Pyrgulopsis sathos']

# %% [markdown]
# The following codeblock lists those cases where the original information from the FWS work plan, either a scientific name or an ITIS taxonomic serial number (pulled from an associated ECOS record), came up with an invalid or unaccepted record in ITIS. In each case, our process followed the ITIS system from the point of discovery to the valid or accepted ITIS record, recording both the valid and original documents in the data cache. The following report shows cases where the FWS Work Plan list may need to be updated with current valid taxonomic names. Synonyms are a factor in all of these records, and we list those names for further consideration. Links to both the valid and invalid ITIS records are provided for followup.

# %%
for record in [i for i in itis_species if "data" in i.keys() and len(i["data"]) > 1]:
    valid_itis_doc = next(x for x in record["data"] if x["usage"] in ["accepted","valid"])
    invalid_itis_doc = next(x for x in record["data"] if x["usage"] not in ["accepted","valid"])
    
    print("input parameter:", record["parameters"])
    print("taxonomic information action:", record["processing_metadata"]["status_message"])
    print("valid itis record:", valid_itis_doc["nameWOInd"])
    print(f"https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value={valid_itis_doc['tsn']}")
    print("invalid itis record:", invalid_itis_doc["nameWOInd"])
    print(f"https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value={invalid_itis_doc['tsn']}")
    print("reason for invalid record:", invalid_itis_doc["unacceptReason"])
    print("synonyms:", valid_itis_doc["synonyms"][0].split(":")[-1][1:-2].split("$"))
    print("==================")
# Out:
# input parameter: {'TSN': '207135'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Anaxyrus microscaphus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=773525
# invalid itis record: Bufo microscaphus microscaphus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=207135
# reason for invalid record: subsequent name/combination
# synonyms: ['Bufo microscaphus', 'Bufo microscaphus microscaphu']
# ==================
# input parameter: {'TSN': '80066'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Amphinaias aurea
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=983630
# invalid itis record: Quadrula aurea
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=80066
# reason for invalid record: subsequent name/combination
# synonyms: ['Quadrula aurea', 'Unio aureu']
# ==================
# input parameter: {'TSN': '80079'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Amphinaias petrina
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=983775
# invalid itis record: Quadrula petrina
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=80079
# reason for invalid record: subsequent name/combination
# synonyms: ['Quadrula petrina', 'Unio petrinus', 'Unio bolli']
# ==================
# input parameter: {'TSN': '173717'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Eurycea wallacei
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=775913
# invalid itis record: Haideotriton wallacei
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=173717
# reason for invalid record: original name/combination
# synonyms: ['Haideotriton wallace']
# ==================
# input parameter: {'TSN': '567231'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Utterbackia heardi
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=983772
# invalid itis record: Anodonta heardi
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=567231
# reason for invalid record: original name/combination
# synonyms: ['Anodonta heard']
# ==================
# input parameter: {'TSN': '894872'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Prosthechea cochleata triandra
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=894898
# invalid itis record: Encyclia cochleata triandra
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=894872
# reason for invalid record: synonym
# synonyms: ['Encyclia cochleata triandra', 'Anacheilium cochleatum triandr', 'Epidendrum cochleatum triandru', 'Encyclia cochleata triandr']
# ==================
# input parameter: {'TSN': '524343'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Nuphar sagittifolia
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=517582
# invalid itis record: Nuphar lutea sagittifolia
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=524343
# reason for invalid record: synonym
# synonyms: ['Nuphar luteum sagittifolium', 'Nymphaea sagittifolia', 'Nymphozanthus sagittifolius', 'Nuphar lutea sagittifoli']
# ==================
# input parameter: {'TSN': '547326'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Nothoceros aenigmaticus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=1063038
# invalid itis record: Megaceros aenigmaticus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=547326
# reason for invalid record: invalidly published, other
# synonyms: ['Megaceros aenigmaticu']
# ==================
# input parameter: {'TSN': '609873'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Capnia gracilaria
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=102712
# invalid itis record: Capnia arapahoe
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=609873
# reason for invalid record: other, see comments
# synonyms: ['Capnia arapahoe', 'Arsapnia arapaho']
# ==================
# input parameter: {'TSN': '183452'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Callitropsis nootkatensis
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=822596
# invalid itis record: Cupressus nootkatensis
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=183452
# reason for invalid record: synonym
# synonyms: ['Chamaecyparis nootkatensis', 'Cupressus nootkatensi']
# ==================
# input parameter: {'TSN': '209559'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Charina umbratica
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=683027
# invalid itis record: Charina bottae umbratica
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=209559
# reason for invalid record: original name/combination
# synonyms: ['Charina bottae umbratic']
# ==================
# input parameter: {'Scientific Name': 'Quincuncina mitchelli'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Fusconaia mitchelli
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=906951
# invalid itis record: Quincuncina mitchelli
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=80357
# reason for invalid record: subsequent name/combination
# synonyms: ['Quincuncina mitchelli', 'Unio mitchelli', 'Quincuncina guadalupensis', 'Quadrula mitchell']
# ==================
# input parameter: {'Scientific Name': 'Quadrula houstonensis'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Amphinaias houstonensis
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=983629
# invalid itis record: Quadrula houstonensis
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=80078
# reason for invalid record: subsequent name/combination
# synonyms: ['Quadrula houstonensis', 'Unio houstonensi']
# ==================
# input parameter: {'Scientific Name': 'Macrhybopsis aestivalis tetranemus'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Macrhybopsis tetranema
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=553282
# invalid itis record: Macrhybopsis aestivalis tetranemus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=914027
# reason for invalid record: subsequent name/combination
# synonyms: ['Macrhybopsis aestivalis tetra']
# ==================
# input parameter: {'Scientific Name': 'Aster puniceus scabricaulis'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Symphyotrichum puniceum scabricaule
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=541115
# invalid itis record: Aster puniceus scabricaulis
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=193007
# reason for invalid record: synonym
# synonyms: ['Aster scabricaulis', 'Aster puniceus scabricauli']
# ==================
# input parameter: {'Scientific Name': 'Aspidoscelis arizonae'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Cnemidophorus inornatus arizonae
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=208930
# invalid itis record: Aspidoscelis arizonae
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=914097
# reason for invalid record: subsequent name/combination
# synonyms: ['Cnemidophorus arizonae', 'Aspidoscelis arizona']
# ==================
# input parameter: {'Scientific Name': 'Sistrurus catenatus edwardsii'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Sistrurus tergeminus edwardsii
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=1058793
# invalid itis record: Sistrurus catenatus edwardsii
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=209511
# reason for invalid record: subsequent name/combination
# synonyms: ['Sistrurus catenatus edwardsii', 'Crotalophorus edwardsi']
# ==================
# input parameter: {'Scientific Name': 'Alces alces andersoni'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Alces americanus americanus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=898420
# invalid itis record: Alces alces andersoni
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=898971
# reason for invalid record: junior synonym
# synonyms: ['Alces pfizenmayeri', 'Alces gigas', 'Alces alces americana', 'Alces alces andersoni', 'Alces alces gigas', 'Alces alces shirasi', 'Alces alces pfizenmayeri', 'Alces americanus shirasi', 'Alces americana anderson']
# ==================
# input parameter: {'Scientific Name': 'Oncidium undulatum'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Trichocentrum undulatum
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=894691
# invalid itis record: Oncidium undulatum
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=504022
# reason for invalid record: synonym
# synonyms: ['Oncidium luridum', 'Oncidium undulatum', 'Oncidium maculatum', 'Lophiaris maculata', 'Trichocentrum maculatu']
# ==================
# input parameter: {'Scientific Name': 'Macroclemys temmincki'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Macrochelys temminckii
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=668671
# invalid itis record: Macroclemys temminckii
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=173755
# reason for invalid record: subsequent name/combination
# synonyms: ['Macroclemys temminckii', 'Chelonura temminckii', 'Testudo planiti']
# ==================
# input parameter: {'Scientific Name': 'Stilosoma extenuatum'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Lampropeltis extenuata
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=1082386
# invalid itis record: Stilosoma extenuatum
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=174277
# reason for invalid record: original name/combination
# synonyms: ['Stilosoma extenuatu']
# ==================
# input parameter: {'Scientific Name': 'Pseudanophthalmus potomaca potomaca'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Pseudanophthalmus potomacus
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=110131
# invalid itis record: Pseudanophthalmus potomaca potomaca
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=933418
# reason for invalid record: other, see comments
# synonyms: ['Pseudanophthalmus potomaca', 'Pseudanophthalmus potomacus po', 'Pseudanophthalmus potomaca po']
# ==================
# input parameter: {'Scientific Name': 'Martes pennanti'}
# taxonomic information action: Followed Accepted TSN
# valid itis record: Pekania pennanti pennanti
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=1086356
# invalid itis record: Martes pennanti
# https://itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180560
# reason for invalid record: subsequent name/combination
# synonyms: ['Martes pennanti', 'Martes pennanti pennanti', 'Mustela pennanti', 'Mustela canadensis', 'Mustela melanorhyncha', 'Mustela nigra', 'Mustela godmani', 'Viverra piscator', 'Mustela canadensis alb']
# ==================
